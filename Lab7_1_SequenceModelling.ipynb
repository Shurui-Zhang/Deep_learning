# %% [markdown]
# <a href="https://colab.research.google.com/github/Shurui-Zhang/Deep_learning/blob/main/Lab7_1_SequenceModelling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Part 1: Sequence Modelling

# %% [markdown]
# __Before starting, we recommend you enable GPU acceleration if you're running on Colab.__

# %%
# Execute this code block to install dependencies when running on colab
try:
    import torch
except:
    from os.path import exists
    from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
    platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())
    cuda_output = !ldconfig -p|grep cudart.so|sed -e 's/.*\.\([0-9]*\)\.\([0-9]*\)$/cu\1\2/'
    accelerator = cuda_output[0] if exists('/dev/nvidia0') else 'cpu'

    # !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-1.0.0-{platform}-linux_x86_64.whl torchvision

try: 
    import torchbearer
except:
    # !pip install torchbearer
# Out:
# Collecting torchbearer
#   Downloading https://files.pythonhosted.org/packages/ff/e9/4049a47dd2e5b6346a2c5d215b0c67dce814afbab1cd54ce024533c4834e/torchbearer-0.5.3-py3-none-any.whl (138kB)
#      |████████████████████████████████| 143kB 8.1MB/s
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from torchbearer) (1.8.1+cu101)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from torchbearer) (4.41.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchbearer) (1.19.5)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.0.0->torchbearer) (3.7.4.3)
# Installing collected packages: torchbearer
# Successfully installed torchbearer-0.5.3

# %% [markdown]
# ## Markov chains
#
# We'll start our exploration of modelling sequences and building generative models using a 1st order Markov chain. The Markov chain is a stochastic model describing a sequence of possible events in which the probability of each event depends only on the state attained in the previous event. In our case we're going to learn a model over a set of characters from an English language text. The events, or states, in our model are the set of possible characters, and we'll learn the probability of moving from one character to the next.
#
# Let's start by loading the data from the web:

# %%
from torchvision.datasets.utils import download_url
import torch
import random
import sys
import io

# Read the data
download_url('https://s3.amazonaws.com/text-datasets/nietzsche.txt', '.', 'nietzsche.txt', None)
text = io.open('./nietzsche.txt', encoding='utf-8').read().lower()
print('corpus length:', len(text))

print(type(text))
# Out:
# Downloading https://s3.amazonaws.com/text-datasets/nietzsche.txt to ./nietzsche.txt
# HBox(children=(FloatProgress(value=0.0, max=600901.0), HTML(value='')))
# corpus length: 600893
# <class 'str'>

# %% [markdown]
# We now need to iterate over the characters in the text and count the times each transition happens:

# %%
transition_counts = dict()
for i in range(0,len(text)-1):
    currc = text[i]
    nextc = text[i+1]
    if currc not in transition_counts:
        transition_counts[currc] = dict()
    if nextc not in transition_counts[currc]:
        transition_counts[currc][nextc] = 0
    transition_counts[currc][nextc] += 1
print(transition_counts)
# Out:
# {'p': {'r': 1533, 'p': 421, 'o': 1259, 'e': 1901, 'h': 778, 'a': 822, '.': 10, 'i': 632, 'u': 314, 's': 321, 'l': 790, 't': 417, ',': 31, ' ': 157, 'y': 23, '\n': 13, 'n': 6, 'm': 30, '?': 1, 'w': 5, 'b': 1, 'f': 7, 'g': 1, '"': 2, ';': 2, '-': 4, ':': 3}, 'r': {'e': 7222, 'u': 562, 'o': 1987, ' ': 4027, 's': 1337, 'r': 325, 'i': 2450, 't': 1289, '\n': 362, 'y': 997, 'a': 2279, 'h': 210, 'm': 552, 'd': 797, ',': 501, 'w': 52, 'l': 337, 'v': 170, '-': 141, 'c': 274, 'p': 158, 'n': 434, '?': 24, 'f': 141, '.': 111, 'g': 130, 'k': 116, ')': 10, '!': 15, ':': 35, ';': 25, 'b': 83, '"': 25, "'": 33, '_': 6, '[': 2, ']': 3, 'x': 1, '=': 1}, 'e': {'f': 641, '\n': 1571, 'n': 5574, 'r': 7885, ' ': 15665, 'c': 1468, 'y': 555, 'e': 1334, 'd': 3223, 's': 5421, 'i': 857, 'm': 1311, 't': 1348, 'v': 1566, 'l': 2885, ',': 1417, 'a': 2590, 'g': 417, 'p': 569, '.': 374, '-': 270, 'u': 153, 'o': 231, '"': 89, 'x': 756, 'w': 342, 'j': 30, '?': 79, 'z': 5, ';': 92, '!': 69, 'h': 97, '_': 11, 'b': 120, 'q': 249, ':': 109, ')': 41, "'": 104, 'k': 69, ']': 7, 'ë': 1}, 'f': {'a': 687, 'o': 1771, ' ': 4906, ',': 126, 'f': 434, 'e': 992, 'i': 867, ')': 4, 't': 208, 'u': 528, '.': 59, 'r': 741, '\n': 438, '-': 148, '"': 10, 'l': 210, ':': 14, '!': 8, 'n': 3, 'y': 40, ';': 13, '?': 7, 's': 3, "'": 1, ']': 4}, 'a': {'c': 1356, 't': 5417, ' ': 1949, 'n': 8547, 'l': 4251, 'r': 3236, 's': 3564, 'v': 708, 'i': 1252, 'd': 993, 'g': 633, 'y': 922, 'k': 472, 'b': 813, 'p': 756, 'm': 747, 'u': 420, 'f': 163, 'w': 178, ',': 40, '\n': 197, 'z': 24, 'x': 28, 'o': 20, '.': 18, '-': 16, "'": 2, 'j': 16, 'h': 13, 'e': 27, ':': 2, 'a': 2, ')': 4, '!': 1, ';': 1, '"': 3, 'q': 1, '_': 3, '[': 1}, 'c': {'e': 2612, 't': 1449, 'l': 348, 'h': 2208, 'o': 2329, 'i': 1139, 'a': 1573, 'u': 429, 'r': 456, ' ': 267, 'k': 226, 'c': 297, '\n': 38, 's': 68, 'y': 105, '-': 9, "'": 6, ',': 36, 'q': 28, 'n': 2, '.': 15, '"': 3, '?': 2, ')': 4, ';': 4, ':': 1, ']': 1}, '\n': {'\n': 898, 's': 638, 'f': 317, 'd': 304, 't': 1120, 'w': 439, 'a': 910, 'i': 655, 'h': 370, '(': 32, 'e': 338, 'p': 425, 'b': 267, 'l': 157, 'c': 430, 'm': 376, 'y': 21, 'o': 516, 'u': 114, 'g': 151, 'n': 195, 'k': 38, '1': 168, 'q': 15, 'r': 240, 'v': 79, '2': 121, "'": 2, '"': 125, '3': 24, '4': 23, 'j': 26, '5': 23, '6': 24, '7': 24, '8': 23, '9': 22, ' ': 117, '[': 25, '-': 1, '=': 137, '_': 4}, 's': {'u': 1277, 'i': 1943, ' ': 10897, 'p': 877, 'o': 1973, ',': 1519, 't': 4597, 'e': 4028, 'n': 84, 's': 1705, 'y': 254, 'k': 124, 'h': 816, 'a': 809, 'c': 661, 'l': 198, 'm': 263, '.': 471, '\n': 990, ':': 129, '"': 95, 'q': 18, '-': 185, '?': 76, '!': 90, 'd': 29, ')': 54, ';': 128, "'": 5, 'b': 6, 'g': 37, 'w': 54, 'f': 76, 'r': 10, 'v': 3, '_': 5, ']': 12, '[': 1, '=': 1}, 'u': {'p': 527, 't': 1536, 'n': 1426, 's': 2130, 'm': 440, 'a': 565, 'r': 1992, 'e': 615, 'f': 122, 'c': 700, 'l': 1522, 'b': 241, 'd': 301, 'g': 526, 'i': 365, 'o': 44, ' ': 98, ':': 1, 'j': 1, 'u': 5, 'x': 13, ',': 14, '\n': 15, 'v': 4, 'z': 4, "'": 2, 'y': 2, '?': 5, '.': 1, 'h': 1, '!': 2, 'k': 1}, 'o': {'s': 1420, 'm': 1903, 't': 1656, 'u': 3502, 'r': 4541, 'p': 980, ' ': 4176, 'g': 324, 'd': 728, 'w': 1515, 'n': 6283, 'f': 4863, 'o': 768, 'l': 1021, 'b': 379, '-': 55, 'i': 251, '\n': 364, ':': 7, 'c': 380, "'": 11, 'y': 93, 'k': 183, '?': 10, ',': 156, 'a': 90, 'e': 265, 'v': 550, 'z': 8, 'h': 18, '.': 30, '!': 15, '"': 2, ';': 3, ')': 3, 'x': 29, 'q': 5, 'j': 2, ']': 2}, 'i': {'n': 9384, 's': 5423, 'l': 1812, 'b': 343, 'o': 2895, 'm': 1498, 't': 5328, 'c': 2588, 'd': 828, 'r': 1363, 'e': 1341, 'f': 918, 'z': 193, 'v': 981, 'a': 706, 'g': 1096, 'q': 18, 'u': 66, '.': 11, 'p': 164, '\n': 15, ' ': 275, 'k': 186, 'i': 11, 'h': 11, 'x': 36, '-': 24, '_': 3, '"': 6, ',': 19, 'w': 1, ')': 2, '?': 2, ':': 1}, 'n': {'g': 3725, '-': 154, '?': 35, 'o': 2220, 'd': 6044, ' ': 6878, '\n': 593, 'e': 3026, 'i': 1042, 's': 2116, 'n': 277, 'l': 386, ';': 56, 't': 3183, ',': 710, 'a': 1190, 'c': 1946, 'y': 386, 'f': 221, 'v': 168, 'j': 104, ':': 73, 'b': 11,  ...

# %% [markdown]
# The `transition_counts` dictionary maps the current character to the next character, and this is then mapped to a count. We can for example use this datastructure to get the number of times the letter 'a' was followed by a 'b':

# %%
print("Number of transitions from 'a' to 'b': " + str(transition_counts['a']['b']))
# Out:
# Number of transitions from 'a' to 'b': 813

# %% [markdown]
# Finally, to complete the model we need to normalise the counts for each initial character into a probability distribution over the possible next character. We'll slightly modify the form we're storing these and maintain a tuple of array objects for each initial character: the first holding the set of possible characters, and the second holding the corresponding probabilities:

# %%
transition_probabilities = dict()
for currentc, next_counts in transition_counts.items():
    values = []
    probabilities = []
    sumall = 0
    for nextc, count in next_counts.items():
        values.append(nextc)
        probabilities.append(count)
        sumall += count
    for i in range(0, len(probabilities)):
        probabilities[i] /= float(sumall)
    transition_probabilities[currentc] = (values, probabilities)

print(transition_probabilities)
# Out:
# {'p': (['r', 'p', 'o', 'e', 'h', 'a', '.', 'i', 'u', 's', 'l', 't', ',', ' ', 'y', '\n', 'n', 'm', '?', 'w', 'b', 'f', 'g', '"', ';', '-', ':'], [0.16164065795023197, 0.044390552509489666, 0.1327498945592577, 0.20044285111767188, 0.08203289751159848, 0.08667229017292281, 0.001054407423028258, 0.06663854913538592, 0.03310839308308731, 0.03384647827920709, 0.0832981864192324, 0.043968789540278365, 0.0032686630113876003, 0.016554196541543654, 0.002425137072964994, 0.0013707296499367355, 0.0006326444538169548, 0.0031632222690847742, 0.00010544074230282581, 0.000527203711514129, 0.00010544074230282581, 0.0007380851961197807, 0.00010544074230282581, 0.00021088148460565162, 0.00021088148460565162, 0.00042176296921130323, 0.0003163222269084774]), 'r': (['e', 'u', 'o', ' ', 's', 'r', 'i', 't', '\n', 'y', 'a', 'h', 'm', 'd', ',', 'w', 'l', 'v', '-', 'c', 'p', 'n', '?', 'f', '.', 'g', 'k', ')', '!', ':', ';', 'b', '"', "'", '_', '[', ']', 'x', '='], [0.26528063473405816, 0.020643549808992065, 0.07298707023214811, 0.14792095210108727, 0.04911107846018219, 0.011937995885982957, 0.08999412283279459, 0.04734792829856009, 0.013297090802233324, 0.03662209814869233, 0.08371290038201587, 0.007713781957096679, 0.02027622685865413, 0.02927563914193359, 0.018402879811930648, 0.001910079341757273, 0.012378783426388481, 0.006244490155744931, 0.005179253599764913, 0.010064648839259477, 0.005803702615339406, 0.01594181604466647, 0.000881575080811049, 0.005179253599764913, 0.004077284748751102, 0.004775198354393183, 0.004260946223920071, 0.0003673229503379371, 0.0005509844255069057, 0.0012856303261827799, 0.0009183073758448428, 0.003048780487804878, 0.0009183073758448428, 0.0012121657361151925, 0.00022039377020276226, 7.346459006758743e-05, 0.00011019688510138113, 3.6732295033793715e-05, 3.6732295033793715e-05]), 'e': (['f', '\n', 'n', 'r', ' ', 'c', 'y', 'e', 'd', 's', 'i', 'm', 't', 'v', 'l', ',', 'a', 'g', 'p', '.', '-', 'u', 'o', '"', 'x', 'w', 'j', '?', 'z', ';', '!', 'h', '_', 'b', 'q', ':', ')', "'", 'k', ']', 'ë'], [0.010755935900662808, 0.026361271918785133, 0.09353133652152026, 0.13230975752999413, 0.26285762228374865, 0.024632939004950078, 0.00931286181726655, 0.02238442822384428, 0.054081718264955114, 0.0909640070475711, 0.014380401040355735, 0.021998489806191793, 0.022619347260676232, 0.026277372262773723, 0.04841010151858378, 0.023777162513633696, 0.043460021813910565, 0.006997231311351624, 0.009547780854098499, 0.006275694269653494, 0.004530581424616159, 0.002567329473949157, 0.0038761641077271584, 0.0014934138770031043, 0.012685627988925245, 0.005738736471180468, 0.0005033979360684622, 0.0013256145649802836, 8.389965601141036e-05, 0.0015437536706099505, 0.0011578152529574629, 0.0016276533266213608, 0.00018457924322510277, 0.0020135917442738486, 0.004178202869368235, 0.0018290125010487458, 0.0006879771792935649, 0.0017451128450373353, 0.0011578152529574629, 0.0001174595184159745, 1.677993120228207e-05]), 'f': (['a', 'o', ' ', ',', 'f', 'e', 'i', ')', 't', 'u', '.', 'r', '\n', '-', '"', 'l', ':', '!', 'n', 'y', ';', '?', 's', "'", ']'], [0.05621011291114384, 0.14490263459335626, 0.4014072983145148, 0.010309278350515464, 0.035509736540664374, 0.08116511209294715, 0.07093765341188021, 0.0003272786777941417, 0.017018491245295368, 0.043200785468826705, 0.0048273604974635904, 0.06062837506136475, 0.035837015218458515, 0.012109311078383244, 0.0008181966944853543, 0.01718213058419244, 0.001145475372279496, 0.0006545573555882834, 0.0002454590083456063, 0.003272786777941417, 0.0010636557028309605, 0.000572737686139748, 0.0002454590083456063, 8.181966944853542e-05, 0.0003272786777941417]), 'a': (['c', 't', ' ', 'n', 'l', 'r', 's', 'v', 'i', 'd', 'g', 'y', 'k', 'b', 'p', 'm', 'u', 'f', 'w', ',', '\n', 'z', 'x', 'o', '.', '-', "'", 'j', 'h', 'e', ':', 'a', ')', '!', ';', '"', 'q', '_', '['], [0.03685183172083922, 0.14721708881400153, 0.05296771388194369, 0.2322806826829003, 0.11552886183280792, 0.08794434177628004, 0.0968583541689314, 0.01924122187194 ...

# %% [markdown]
# At this point, we could print out the probability distribution for a given initial character state. For example, to print the distribution for 'a':

# %%
for a,b in zip(transition_probabilities['a'][0], transition_probabilities['a'][1]):
    print(a,b)
# Out:
# c 0.03685183172083922
# t 0.14721708881400153
#   0.05296771388194369
# n 0.2322806826829003
# l 0.11552886183280792
# r 0.08794434177628004
# s 0.0968583541689314
# v 0.0192412218719426
# i 0.03402543754755952
# d 0.026986628981411024
# g 0.017202956843135123
# y 0.02505707142080661
# k 0.012827481247961734
# b 0.02209479291227307
# p 0.020545711490379388
# m 0.02030111968692249
# u 0.011414284161321883
# f 0.004429829329274921
# w 0.004837482335036417
# , 0.0010870746820306554
#
#  0.005353842809000978
# z 0.0006522448092183933
# x 0.0007609522774214588
# o 0.0005435373410153277
# . 0.000489183606913795
# - 0.0004348298728122622
# ' 5.4353734101532776e-05
# j 0.0004348298728122622
# h 0.00035329927165996303
# e 0.0007337754103706925
# : 5.4353734101532776e-05
# a 5.4353734101532776e-05
# ) 0.00010870746820306555
# ! 2.7176867050766388e-05
# ; 2.7176867050766388e-05
# " 8.153060115229916e-05
# q 2.7176867050766388e-05
# _ 8.153060115229916e-05
# [ 2.7176867050766388e-05

# %% [markdown]
# It looks like the most probable letter to follow an 'a' is 'n'.
#
# __What is the most likely letter to follow the letter 'j'? Write your answer in the block below:__

# %%
for a,b in zip(transition_probabilities['j'][0], transition_probabilities['j'][1]):
    print(a,b)

print(max(transition_probabilities['j'][1]))
# Out:
# e 0.2585278276481149
# o 0.15080789946140036
# u 0.5709156193895871
# a 0.017953321364452424
# i 0.0017953321364452424
# 0.5709156193895871

# %% [markdown]
# We mentioned earlier that the Markov model is generative. This means that we can draw samples from the distributions and iteratively move between states.
#
# Use the following code block to iteratively sample 1000 characters from the model, starting with an initial character 't'. You can use the `torch.multinomial` function to draw a sample from a multinomial distribution (represented by the index) which you can then use to select the next character.

# %%
current = 't'

characters = []
for i in range(0, 1000):
    print(current, end='')
    # sample the next character based on `current` and store the result in `current`
    characterProbability = transition_probabilities[current]
    probability = torch.Tensor(characterProbability[1])
    index = torch.multinomial(probability, 1)
    characters.append(current)
    current = characterProbability[0][index]

print(current)
print("-----------")
print(characters)
print("-----------")
# Out:
# tinin, bjell frous orif taved m, wsengglullf d  sely alathncef ms csco anidiole han thithous hes
#
# th t pede ateithemsprevere m the, risellasheplelompathaler
# tendn prs o therd rvik thangien thon-aloo asake lul ghiowoly-akentive wonadathatithatthe burd orf ve ond, ind ldy, a cino ar hy oye
# g, alousiralofot ioaun o weariren r"tin pocty f co rde
# sthaby or anoumo athe is io, atith erisythiral
# o rsy pove he d wis lldghe t be t toninsowios onsteaincepols wh, htincos nd me cereirouit (otathoran prthig kekinthan, alw acof is derofr mprendin evid thiceat as e al itrhinthicourin ton winge ith wompouan ve,
# a pperul, avene incro  oosntan bthane
# juenqual d oiorwa tanexpthe"typprseche the orme oofumo s f? flff
# binth d
# throned
# rsthig thalabr thasis aiclunciangru throfild an
# t rety! urus s l icictorin
# on--f whalog o thuly of,
# 24
# "blleitind ff ofexensitueasse-cthevee beig
# penghe
# me ot ser inthit  t mevomel opood otrom borsupond.=f o
# womomovexphecer atof tsin ive wheilyinhor as bag o thes,
# andosusulyeef o
# -----------
# ['t', 'i', 'n', 'i', 'n', ',', ' ', 'b', 'j', 'e', 'l', 'l', ' ', 'f', 'r', 'o', 'u', 's', ' ', 'o', 'r', 'i', 'f', ' ', 't', 'a', 'v', 'e', 'd', ' ', 'm', ',', ' ', 'w', 's', 'e', 'n', 'g', 'g', 'l', 'u', 'l', 'l', 'f', ' ', 'd', ' ', ' ', 's', 'e', 'l', 'y', ' ', 'a', 'l', 'a', 't', 'h', 'n', 'c', 'e', 'f', ' ', 'm', 's', ' ', 'c', 's', 'c', 'o', ' ', 'a', 'n', 'i', 'd', 'i', 'o', 'l', 'e', ' ', 'h', 'a', 'n', ' ', 't', 'h', 'i', 't', 'h', 'o', 'u', 's', ' ', 'h', 'e', 's', '\n', '\n', 't', 'h', ' ', 't', ' ', 'p', 'e', 'd', 'e', ' ', 'a', 't', 'e', 'i', 't', 'h', 'e', 'm', 's', 'p', 'r', 'e', 'v', 'e', 'r', 'e', ' ', 'm', ' ', 't', 'h', 'e', ',', ' ', 'r', 'i', 's', 'e', 'l', 'l', 'a', 's', 'h', 'e', 'p', 'l', 'e', 'l', 'o', 'm', 'p', 'a', 't', 'h', 'a', 'l', 'e', 'r', '\n', 't', 'e', 'n', 'd', 'n', ' ', 'p', 'r', 's', ' ', 'o', ' ', 't', 'h', 'e', 'r', 'd', ' ', 'r', 'v', 'i', 'k', ' ', 't', 'h', 'a', 'n', 'g', 'i', 'e', 'n', ' ', 't', 'h', 'o', 'n', '-', 'a', 'l', 'o', 'o', ' ', 'a', 's', 'a', 'k', 'e', ' ', 'l', 'u', 'l', ' ', 'g', 'h', 'i', 'o', 'w', 'o', 'l', 'y', '-', 'a', 'k', 'e', 'n', 't', 'i', 'v', 'e', ' ', 'w', 'o', 'n', 'a', 'd', 'a', 't', 'h', 'a', 't', 'i', 't', 'h', 'a', 't', 't', 'h', 'e', ' ', 'b', 'u', 'r', 'd', ' ', 'o', 'r', 'f', ' ', 'v', 'e', ' ', 'o', 'n', 'd', ',', ' ', 'i', 'n', 'd', ' ', 'l', 'd', 'y', ',', ' ', 'a', ' ', 'c', 'i', 'n', 'o', ' ', 'a', 'r', ' ', 'h', 'y', ' ', 'o', 'y', 'e', '\n', 'g', ',', ' ', 'a', 'l', 'o', 'u', 's', 'i', 'r', 'a', 'l', 'o', 'f', 'o', 't', ' ', 'i', 'o', 'a', 'u', 'n', ' ', 'o', ' ', 'w', 'e', 'a', 'r', 'i', 'r', 'e', 'n', ' ', 'r', '"', 't', 'i', 'n', ' ', 'p', 'o', 'c', 't', 'y', ' ', 'f', ' ', 'c', 'o', ' ', 'r', 'd', 'e', '\n', 's', 't', 'h', 'a', 'b', 'y', ' ', 'o', 'r', ' ', 'a', 'n', 'o', 'u', 'm', 'o', ' ', 'a', 't', 'h', 'e', ' ', 'i', 's', ' ', 'i', 'o', ',', ' ', 'a', 't', 'i', 't', 'h', ' ', 'e', 'r', 'i', 's', 'y', 't', 'h', 'i', 'r', 'a', 'l', '\n', 'o', ' ', 'r', 's', 'y', ' ', 'p', 'o', 'v', 'e', ' ', 'h', 'e', ' ', 'd', ' ', 'w', 'i', 's', ' ', 'l', 'l', 'd', 'g', 'h', 'e', ' ', 't', ' ', 'b', 'e', ' ', 't', ' ', 't', 'o', 'n', 'i', 'n', 's', 'o', 'w', 'i', 'o', 's', ' ', 'o', 'n', 's', 't', 'e', 'a', 'i', 'n', 'c', 'e', 'p', 'o', 'l', 's', ' ', 'w', 'h', ',', ' ', 'h', 't', 'i', 'n', 'c', 'o', 's', ' ', 'n', 'd', ' ', 'm', 'e', ' ', 'c', 'e', 'r', 'e', 'i', 'r', 'o', 'u', 'i', 't', ' ', '(', 'o', 't', 'a', 't', 'h', 'o', 'r', 'a', 'n', ' ', 'p', 'r', 't', 'h', 'i', 'g', ' ', 'k', 'e', 'k', 'i', 'n', 't', 'h', 'a', 'n', ',', ' ', 'a', 'l', 'w', ' ', 'a', 'c', 'o', 'f', ' ', 'i', 's', ' ', 'd', 'e', 'r', 'o', 'f', 'r', ' ', 'm', 'p', 'r', 'e', 'n', 'd', 'i', 'n', ' ', 'e', 'v', 'i', 'd', ' ', 't', 'h', 'i', 'c', 'e', 'a', 't', ' ', 'a', 's', ' ', 'e', ' ', 'a', 'l', ' ', 'i', 't', 'r', 'h', 'i', 'n', 't', 'h', 'i', 'c', 'o', 'u', 'r', 'i', 'n', ' ', 't', 'o', 'n', ' ', 'w', 'i', 'n', 'g', 'e', ' ', 'i', 't', 'h', ' ', 'w', 'o', 'm', 'p', 'o', 'u', 'a', 'n', ' ', 'v', 'e', ',', '\n', 'a', ' ', 'p', 'p', 'e', 'r', 'u', 'l', ',', ' ', 'a', 'v', 'e', 'n', 'e', ' ', 'i', 'n', 'c', 'r', 'o', ' ', ' ', 'o', 'o', 's', 'n', 't', 'a', 'n', ' ', 'b', 't', 'h', 'a', 'n', 'e', '\n', 'j', 'u', 'e', 'n', 'q', 'u', 'a', 'l', ' ', 'd', ' ', 'o', 'i', 'o', 'r', 'w', 'a', ' ', 't', 'a', 'n', 'e', 'x', 'p', 't', 'h', 'e', '"', 't', 'y', 'p', 'p', 'r', 's', 'e', 'c', 'h', 'e', ' ', 't', 'h', 'e', ' ', 'o', 'r', 'm', 'e', ' ', 'o', 'o', 'f', 'u', 'm', 'o', ' ', 's', ' ', 'f', '?', ' ', 'f', 'l', 'f', 'f', '\n', 'b', 'i', 'n', 't', 'h', ' ', 'd', '\n', 't', 'h', 'r', 'o', 'n', 'e', 'd', '\n', 'r', 's', 't', 'h', 'i', 'g', ' ', 't', 'h', 'a', 'l', 'a', 'b', 'r', ' ', 't', 'h', 'a', 's', 'i', 's', ' ', 'a', 'i', 'c', 'l', 'u', 'n', 'c', 'i', 'a', 'n', 'g', 'r', 'u', ' ', 't', 'h', 'r', 'o', 'f', 'i', 'l', 'd', ' ', 'a', 'n', '\n', 't', ' ', 'r', 'e', 't', 'y', '!', ' ', 'u', 'r', 'u', 's', ' ', 's', ' ', 'l', ' ', 'i', 'c', 'i', 'c', 't', 'o', 'r', 'i', 'n', '\n', 'o', ' ...
# -----------

# %% [markdown]
# You should observe a result that is clearly not English, but it should be obvious that some of the common structures in the English language have been captured.
#
# __Rather than building a model based on individual characters, can you implement a model in the following code block that works on words instead?__

# %%
# YOUR CODE HERE
#raise NotImplementedError()

# %% [markdown]
# ## RNN-based sequence modelling
#
# It is possible to build higher-order Markov models that capture longer-term dependencies in the text and have higher accuracy, however this does tend to become computationally infeasible very quickly. Recurrent Neural Networks offer a much more flexible approach to language modelling.
#
# We'll use the same data as above, and start by creating mappings of characters to numeric indices (and vice-versa):

# %%
chars = sorted(list(set(text)))#将全部单个字符按升序排列存入列表中
print('total chars:', len(chars))

char_indices = dict((c, i) for i, c in enumerate(chars)) #将索引与字符按照char_indices对应起来
indices_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# total chars: 57

# %% [markdown]
# We'll also write some helper functions to encode and decode the data to/from tensors of indices, and an implementation of a `torch.Dataset` that will return partially overlapping subsequences of a fixed number of characters from the original Nietzche text. Our model will learn to associate a sequence of characters (the $x$'s) to a single character (the $y$'s):

# %%
from torch.utils.data import Dataset, DataLoader
from torch import nn
from torch.nn import functional as F
from torch import optim
import random
import sys
import io

maxlen = 40
step = 3


def encode(inp):
    # encode the characters in a tensor
    x = torch.zeros(maxlen, dtype=torch.long)
    for t, char in enumerate(inp):
        x[t] = char_indices[char] #x里面存的是字符串inp中每个字符对应的索引

    return x


def decode(ten):
    s = ''
    for v in ten:
        s += indices_char[v] 
    return s


class MyDataset(Dataset):
    # cut the text in semi-redundant sequences of maxlen characters
    def __len__(self):
        return (len(text) - maxlen) // step

    def __getitem__(self, i):
        inp = text[i*step: i*step + maxlen]
        out = text[i*step + maxlen]

        x = encode(inp)
        y = char_indices[out]

        return x, y

# %% [markdown]
# We can now define the model. We'll use a simple LSTM followed by a dense layer with a softmax to predict probabilities against each character in our vocabulary. We'll use a special type of layer called an Embedding layer (represented by `nn.Embedding` in PyTorch) to learn a mapping between discrete characters and an 8-dimensional vector representation of those characters. You'll learn more about Embeddings in the next part of the lab.

# %%
class CharPredictor(nn.Module):
    def __init__(self):
        super(CharPredictor, self).__init__()
        self.emb = nn.Embedding(len(chars), 8) #57 8
        self.lstm = nn.LSTM(8, 128, batch_first=True)
        self.lin = nn.Linear(128, len(chars)) #128 57

    def forward(self, x):
        x = self.emb(x)
        lstm_out, _ = self.lstm(x)
        out = self.lin(lstm_out[:,-1]) #we want the final timestep output (timesteps in last index with batch_first) 只取lstm处理结果的最后一列 out为torch.Size([1, 57])
        print("ooooooooooooooouuuuuuuuuuuuutttttttttt", out)
        return out

# %% [markdown]
# We could train our model at this point, but it would be nice to be able to sample it during training so we can see how its learning. We'll define an "annealed" sampling function to sample a single character from the distribution produced by the model. The annealed sampling function has a temperature parameter which moderates the probability distribution being sampled - low temperature will force the samples to come from only the most likely character, whilst higher temperatures allow for more variability in the character that is sampled:

# %%
def sample(logits, temperature=1.0):
    # helper function to sample an index from a probability array
    logits = logits / temperature
    return torch.multinomial(F.softmax(logits, dim=0), 1)

# %% [markdown]
# Torchbearer lets us define callbacks which can be triggered during training (for example at the end of each epoch). Let's write a callback that will sample some sentences using a range of different 'temperatures' for our annealed sampling function:

# %%
import torchbearer
from torchbearer import Trial
from torchbearer.callbacks.decorators import on_end_epoch

device = "cuda:0" if torch.cuda.is_available() else "cpu"

@on_end_epoch
def create_samples(state):
    with torch.no_grad():
        epoch = -1
        if state is not None:
            epoch = state[torchbearer.EPOCH]

        print()
        print('----- Generating text after Epoch: %d' % epoch)

        start_index = random.randint(0, len(text) - maxlen - 1)
        for diversity in [0.2, 0.5, 1.0, 1.2]:
            print()
            print()
            print('----- diversity:', diversity)

            generated = ''
            sentence = text[start_index:start_index+maxlen-1]
            generated += sentence
            print('----- Generating with seed: "' + sentence + '"')
            print()
            sys.stdout.write(generated)

            inputs = encode(sentence).unsqueeze(0).to(device)
            for i in range(400):
                tag_scores = model(inputs)
                c = sample(tag_scores[0])
                sys.stdout.write(indices_char[c.item()])
                sys.stdout.flush()
                inputs[0, 0:inputs.shape[1]-1] = inputs[0, 1:].clone()
                inputs[0, inputs.shape[1]-1] = c
        print()

# %% [markdown]
# Now, all the pieces are in place. __Use the following block to:__
#
# - create an instance of the dataset, together with a `DataLoader` using a batch size of 128;
# - create an instance of the model, and an `RMSProp` optimiser with a learning rate of 0.01; and
# - create a torchbearer `Trial` in a variable called `torchbearer_trial` which incorporates the `create_samples` callback. Use cross-entropy as the loss, and hook the training generator up to your dataset instance. Make sure you move your `Trial` object to the GPU if one is available.

# %%
dataset = MyDataset()
dataLoader = DataLoader(dataset, batch_size=128, shuffle=True)
model = CharPredictor()

optimiser = optim.RMSprop(model.parameters(), lr = 0.01)
loss_function = nn.CrossEntropyLoss()

device = "cuda:0" if torch.cuda.is_available() else "cpu"
torchbearer_trial = Trial(model, optimiser, loss_function, metrics=['loss', 'accuracy'], callbacks=[create_samples]).to(device)
torchbearer_trial.with_generators(dataLoader)
# Out:
# --------------------- OPTIMZER ---------------------
# RMSprop (
# Parameter Group 0
#     alpha: 0.99
#     centered: False
#     eps: 1e-08
#     lr: 0.01
#     momentum: 0
#     weight_decay: 0
# )
#
# -------------------- CRITERION ---------------------
# CrossEntropyLoss()
#
# --------------------- METRICS ----------------------
# ['loss', 'acc']
#
# -------------------- CALLBACKS ---------------------
# ['torchbearer.callbacks.decorators.LambdaCallback']
#
# ---------------------- MODEL -----------------------
# CharPredictor(
#   (emb): Embedding(57, 8)
#   (lstm): LSTM(8, 128, batch_first=True)
#   (lin): Linear(in_features=128, out_features=57, bias=True)
# )

# %% [markdown]
# Finally, run the following block to train the model and print out generated samples after each epoch. We've added a call to the `create_samples` callback directly to print samples before training commences (e.g. with random weights). Be aware this will take some time to run...

# %%
create_samples.on_end_epoch(None)
torchbearer_trial.run(epochs=10)
# Out:
# ----- Generating text after Epoch: -1
#
#
# ----- diversity: 0.2
# ----- Generating with seed: " man, and he who perpetually tears and "
#
#  man, and he who perpetually tears and ooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[-0.0403, -0.0111, -0.0062, -0.0215, -0.0378, -0.0371, -0.0462, -0.0177,
#          -0.0895, -0.0402, -0.0118, -0.0506, -0.0680, -0.0450,  0.0889,  0.0811,
#          -0.0796,  0.0212,  0.0865, -0.0074, -0.0012, -0.0314, -0.0508, -0.0423,
#          -0.0228, -0.0485,  0.0055,  0.0157, -0.0633,  0.0087, -0.1199,  0.0778,
#          -0.0711,  0.0890, -0.0130,  0.0744, -0.1245,  0.0559, -0.0801,  0.0243,
#          -0.0234, -0.0278, -0.0710,  0.1300,  0.0033,  0.0062,  0.0283, -0.1065,
#          -0.1031,  0.0233, -0.0336, -0.0224, -0.0652,  0.0554, -0.0057, -0.0455,
#          -0.0011]], device='cuda:0')
# .ooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[-0.0073,  0.0056,  0.0077, -0.0372, -0.0313,  0.0028, -0.0687,  0.0171,
#          -0.0813, -0.0368, -0.0579, -0.0155, -0.0426, -0.0005,  0.0528,  0.0656,
#          -0.0899, -0.0031,  0.0681,  0.0565,  0.0190, -0.0588,  0.0392, -0.0604,
#          -0.0538, -0.0630,  0.0179,  0.0049, -0.0059,  0.0517, -0.1008, -0.0092,
#          -0.0795,  0.0697,  0.0047,  0.0882, -0.0990,  0.0102, -0.0510, -0.0173,
#          -0.0380, -0.0539, -0.1089,  0.0125,  0.0860, -0.0024, -0.0150, -0.0810,
#          -0.0709,  0.0147, -0.0527,  0.0072, -0.0007,  0.0630, -0.0133, -0.0322,
#           0.0089]], device='cuda:0')
# ëooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[-0.0075,  0.0066,  0.0094, -0.0118, -0.0378,  0.0016, -0.0624, -0.0346,
#          -0.0615, -0.0423, -0.0578, -0.0253, -0.0219, -0.0268,  0.0886,  0.0648,
#          -0.1125, -0.0199,  0.0784,  0.0236, -0.0010, -0.0546,  0.0275, -0.0546,
#          -0.0588, -0.0647, -0.0030,  0.0034, -0.0242,  0.0317, -0.1177,  0.0530,
#          -0.0869,  0.0869, -0.0125,  0.0776, -0.1190,  0.0565, -0.0481,  0.0314,
#          -0.0231, -0.0310, -0.0847,  0.0607,  0.0144, -0.0121,  0.0183, -0.1097,
#          -0.0634,  0.0142, -0.0158, -0.0061, -0.0565,  0.0673, -0.0284, -0.0145,
#          -0.0049]], device='cuda:0')
# looooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 0.0096,  0.0186,  0.0209, -0.0152, -0.0383,  0.0118, -0.0409, -0.0273,
#          -0.0639, -0.0400, -0.0537, -0.0172, -0.0285, -0.0388,  0.1061,  0.0499,
#          -0.1218, -0.0098,  0.0723,  0.0305,  0.0356, -0.0448,  0.0376, -0.0634,
#          -0.0667, -0.0650,  0.0028,  0.0239, -0.0114,  0.0439, -0.1043,  0.0264,
#          -0.0600,  0.0600, -0.0018,  0.0850, -0.1127,  0.0577, -0.0420,  0.0160,
#          -0.0303, -0.0358, -0.1042,  0.0507,  0.0400, -0.0172,  0.0064, -0.1021,
#          -0.0571,  0.0149, -0.0277, -0.0021, -0.0579,  0.0657, -0.0243, -0.0103,
#           0.0030]], device='cuda:0')
# aooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 0.0050,  0.0127, -0.0021, -0.0030, -0.0247,  0.0117, -0.0339, -0.0527,
#          -0.0397, -0.0387, -0.0757, -0.0077, -0.0125, -0.0317,  0.0800,  0.0583,
#          -0.0827,  0.0058,  0.0432,  0.0380,  0.0334, -0.0558, -0.0085, -0.0336,
#          -0.0258, -0.0558,  0.0286,  0.0325, -0.0508,  0.0356, -0.0999,  0.0290,
#          -0.0420,  0.0814, -0.0180,  0.0474, -0.1129,  0.0535, -0.0692,  0.0118,
#          -0.0209, -0.0249, -0.1029,  0.0670,  0.0404, -0.0140,  0.0025, -0.0820,
#          -0.1014,  0.0274, -0.0611, -0.0194, -0.0571,  0.0619, -0.0072, -0.0233,
#          -0.0065]], device='cuda:0')
# mooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 0.0032,  0.0038,  0.0006, -0.0304, -0.0213, -0.0050, -0.0274, -0.0230,
#          -0.0707, -0.0325, -0.0527, -0.0261, -0.0512, -0.0357,  0.0723,  0.0519,
#          -0.0688,  0.0258,  0.0474,  0.0360,  0.0657, -0.0347, -0.0228, -0.0524,
#          -0.0386, -0.0563,  0.0471,  0.0446, -0.0373,  0.0330, -0.0757,  0.0033,
#          -0.0362,  0.0452,  0.0054,  0.0758, -0.0984,  0.0287, -0.0760, -0.0147,
#          -0.0385, -0.0433, -0.1067,  0.0563,  0.0620, -0.0098, -0.0014, -0.0769,
#          -0.0965,  0.0390, -0.0589, -0.0190, -0.0491,  0.0626, -0.0042, -0.0401,
#           0.0139]], device='cuda:0')
# 8ooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 0.0134,  0.0132,  0.0120, -0.0352, -0.0437, -0.0264, -0.0469, -0.0045,
#          -0.0904, -0.0371, -0.0319, -0.0312, -0.0826, -0.0168,  0.0741,  0.0725,
#          -0.0825,  0.0336,  0.0687,  0.0384,  0.0500, -0.0452,  0.0004, -0.0879,
#          -0.0798, -0.0667,  0.0399,  0.0253,  0.0004,  0.0740, -0.0852, -0.0224,
#          -0.0316,  0.0038,  0.0431,  0.1061, -0.0861,  0.0046, -0.0800, -0.0484,
#          -0.0706, -0.0365, -0.1413,  0.0479,  0.0985, -0.0258, -0.0259, -0.0764,
#          -0.0594,  0.0078, -0.0408, -0.0028, -0.0401,  0.0887, -0.0078, -0.0023,
#           0.0319]], device='cuda:0')
# 1ooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 0.0237,  0.0297,  0.0339, -0.0205, -0.0579, -0.0101, -0.0615, -0.0222,
#          -0.0667, -0.0607, -0.0441, -0.0148, -0.0591,  0.0015,  0.0967,  0.0758,
#          -0.1220,  0.0023,  0.0866,  0.0512,  0.0160, -0.0622,  0.0529, -0.0986,
#          -0.0938, -0.0721,  0.0140,  0.0088,  0.0194,  0.0939, -0.1132, -0.0213,
#          -0.0543,  0.0218,  0.0280,  0.1069, -0.1078,  0.0247, -0.0630, -0.0434,
#          -0.0675, -0.0187, -0.1588,  0.0260,  0.0873, -0.0431, -0.0336, -0.0984,
#          -0.0393, -0.0188, -0.0263,  0.0093, -0.0364,  0.0954, -0.0215,  0.0259,
#           0.0142]], device='cuda:0')
# 7ooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[-0.0039,  0.0125,  0.0043, -0.0022, -0.0429,  0.0251, -0.0845, -0.0195,
#          -0.0566, -0.0236, -0.0595, -0.0019, -0.0395,  0.0034,  0.0715,  0.0743,
#          -0.0770, -0.0418,  0.0580,  0.0340,  0.0361, -0.0766,  0.0474, -0.0668,
#          -0.0655, -0.1062,  0.0395,  0.0121,  0.0066,  0.0927, -0.1097,  0.0003,
#          -0.0613,  0.0163,  0.0351,  0.1074, -0.1124,  0.0225, -0.0373, -0.0021,
#          -0.0495, -0.0456, -0.1082,  0.0126,  0.0826, -0.0367, -0.0043, -0.0726,
#          -0.0230, -0.0010, -0.0238,  0.0443, -0.0297,  0.0534, -0.0297,  0.0259,
#           0.0396]], device='cuda:0')
# 1ooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 0.0179,  0.0351,  0.0287, -0.0043, -0.0523,  0.0145, -0.0812, -0.0404,
#          -0.0557, -0.0518, -0.0614, -0.0054, -0.0316,  0.0079,  0.0964,  0.0761,
#          -0.1187, -0.0355,  0.0776,  0.0489,  0.0103, -0.0804,  0.0793, -0.0925,
#          -0.0886, -0.0879,  0.0167, -0.0034,  0.0210,  0.1056, -0.1257, -0.0033,
#          -0.0691,  0.0330,  0.0307,  0.1093, -0.1194,  0.0321, -0.0383, -0.0132,
#          -0.0610, -0.0263, -0.1435,  0.0086,  0.0829, -0.0488, -0.0196, -0.0957,
#          -0.0183, -0.0146, -0.0146,  0.0367, -0.0311,  0.0739, -0.0327,  0.0384,
#           0.0202]], device='cuda:0')
#  ooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[-0.0159,  0.0018,  0.0088, -0.0374, -0.0608, -0.0752, -0.0817, -0.0417,
#          -0.1006, -0.0607, -0.0105, -0.0574, -0.0689, -0.0081,  0.0876,  0.0828,
#          -0.0979,  0.0007,  0.1094,  0.0210, -0.0326, -0.0560,  0.0047, -0.0953,
#          -0.0787, -0.0469,  0.0031, -0.0106, -0.0264,  0.0526, -0.1307,  0.0646,
#          -0.0850,  0.0835,  0.0270,  0.1012, -0.1364,  0.0421, -0.0696,  0.0033,
#          -0.0666, -0.0230, -0.0952,  0.0787,  0.0291, -0.0004,  0.0112, -0.1330,
#          -0.0482,  0.0105,  0.0064, -0.0028, -0.0324,  0.0554, -0.0326, -0.0424,
#           0.0165]], device='cuda:0')
# 6ooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 0.0079,  0.0214,  0.0219, -0.0263, -0.0692, -0.0410, -0.0935, -0.0284,
#          -0.0860, -0.0610, -0.0380, -0.0318, -0.0364,  0.0155,  0.0820,  0.0937,
#          -0.1237, -0.0082,  0.0978,  0.0358, -0.0416, -0.0779,  0.0368, -0.0908,
#          -0.0797, -0.0619, -0.0068, -0.0351, -0.0026,  0.0815, -0.1562,  0.0385,
#          -0.0843,  0.0727,  0.0167,  0.0954, -0.1201,  0.0336, -0.0620, -0.0037,
#          -0.0509, -0.0126, -0.1174,  0.0519,  0.0467, -0.0124, -0.0142, -0.1131,
#          -0.0460, -0.0185, -0.0060,  0.0012, -0.0317,  0.0852, -0.0264,  0.0072,
#          -0.0006]], device='cuda:0')
# 0ooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 0.0129,  0.0212,  0.0214, -0.0256, -0.0346,  0.0087, -0.0378, -0.0312,
#          -0.0669, -0.0591, -0.0603, -0.0144, -0.0269, -0.0243,  0.0898,  0.0642,
#          -0.1070, -0.0048,  0.0669,  0.0419,  0.0220, -0.0543,  0.0163, -0.0481,
#          -0.0454, -0.0590,  0.0083, -0.0014, -0.0259,  0.0503, -0.1105,  0.0186,
#          -0.0532,  0.0802, -0.0065,  0.0735, -0.1130,  0.0527, -0.0622,  0.0071,
#          -0.0194, -0.0269, -0.0978,  0.0562,  0.0339, -0.0149, -0.0122, -0.0923,
#          -0.0850,  0.0109, -0.0475, -0.0147, -0.0532,  0.0717, -0.0021, -0.0190,
#          -0.0155]], device='cuda:0')
# ,ooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 0.0004, -0.0079,  0.0233, -0.0275, -0.0423, -0.0125, -0.0499, -0.0106,
#          -0.1075, -0.0441, -0.0354, -0.0346, -0.0287, -0.0197,  0.0796,  0.0835,
#          -0.1040, -0.0250,  0.1010,  0.0263,  0.0180, -0.0515,  0.0271, -0.0809,
#          -0.0921, -0.0915,  0.0229, -0.0298, -0.0029,  0.0590, -0.1205,  0.0221,
#          -0.0845,  0.0388,  0.0224,  0.1143, -0.0895,  0.0193, -0.0569,  0.0271,
#          -0.0467, -0.0367, -0.0954,  0.0468,  0.0310, -0.0368, -0.0129, -0.0906,
#          -0.0354,  0.0113,  0.0067,  0.0290, -0.0476,  0.0873, -0.0256, -0.0007,
#           0.0114]], device='cuda:0')
# äooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[-0.0465, -0.0451,  0.0130, -0.0398, -0.0232, -0.0269, -0.0313, -0.0118,
#          -0.1347, -0.0501, -0.0516, -0.0470, -0.0084, -0.0415,  0.0424,  0.0811,
#          -0.0870, -0.0249,  0.1122,  0.0178,  0.0012, -0.0457, -0.0014, -0.0616,
#          -0.0813, -0.0842,  0.0336, -0.0421, -0.0439,  0.0060, -0.1150,  0.0710,
#          -0.1430,  0.0868, -0.0051,  0.0944, -0.0840,  0.0082, -0.0644,  0.0927,
#          -0.0403, -0.0403, -0.0563,  0.0508, -0.0154, -0.0220,  0.0068, -0.1000,
#          -0.0581,  0.0599,  0.0319,  0.0299, -0.0338,  0.0659, -0.0443, -0.0612,
#          -0.0023]], device='cuda:0')
# yooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[-0.0167, -0.0086, -0.0010, -0.0099, -0.0375, -0.0160, -0.0664, -0.0212,
#          -0.0924, -0.0411, -0.0537, -0.0296, -0.0066, -0.0086,  0.0475,  0.0915,
#          -0.0796, -0.0134,  0.0786,  0.0285, -0.0120, -0.0754,  0.0039, -0.0607,
#          -0.0603, -0.0758,  0.0165, -0.0361, -0.0267,  0.0524, -0.1424,  0.0559,
#          -0.0996,  0.0725,  0.0039,  0.0792, -0.0926,  0.0078, -0.0680,  0.0494,
#          -0.0277, -0.0191, -0.0992,  0.0539,  0.0389, -0.0125, -0.0109, -0.0731,
#          -0.0693,  0.0164,  0.0003,  0.0243, -0.0211,  0.0834, -0.0281, -0.0092,
#           0.0017]], device='cuda:0')
# .ooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 0.0087,  0.0091,  0.0121, -0.0353, -0.0206,  0.0185, -0.0797,  0.0088,
#          -0.0863, -0.0481, -0.0733, -0.0125, -0.0163,  0.0149,  0.0352,  0.0653,
#          -0.0760, -0.0254,  0.0664,  0.0737,  0.0117, -0.0799,  0.0589, -0.0753,
#          -0.0655, -0.0792,  0.0278, -0.0333,  0.0060,  0.0741, -0.1046, -0.0134,
#          -0.0984,  0.0584,  0.0231,  0.0919, -0.0887, -0.0168, -0.0453, -0.0018,
#          -0.0405, -0.0475, -0.1201, -0.0268,  0.1016, -0.0141, -0.0385, -0.0605,
#          -0.0506,  0.0181, -0.0293,  0.0341,  0.0222,  0.0733, -0.0187, -0.0175,
#           0.0107]], device='cuda:0')
# zooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[-0.0119,  0.0071, -0.0110, -0.0158, -0.0114,  0.0430, -0.0746,  0.0007,
#          -0.0795, -0.0234, -0.0746,  0.0018, -0.0269,  0.0035,  0.0335,  0.0404,
#          -0.0352, -0.0432,  0.0440,  0.0534,  0.0600, -0.0695,  0.0508, -0.0596,
#          -0.0418, -0.0892,  0.0615,  0.0122, -0.0065,  0.0602, -0.0737, -0.0072,
#          -0.0784,  0.0270,  0.0359,  0.0905, -0.1064, -0.0155, -0.0332,  0.0023,
#          -0.0461, -0.0709, -0.0985, -0.0321,  0.1183, -0.0129, -0.0119, -0.0444,
#          -0.0496,  0.0497, -0.0312,  0.0510,  0.0082,  0.0329, -0.0199, -0.0238,
#           0.0412]], device='cuda:0')
# ëooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[-0.0112,  0.0037, -0.0024, -0.0001, -0.0231,  0.0200, -0.0691, -0.0536,
#          -0.0506, -0.0303, -0.0732, -0.0205, -0.0159, -0.0247,  0.0773,  0.0562,
#          -0.0833, -0.0428,  0.0610,  0.0247,  0.0209, -0.0631,  0.0284, -0.0544,
#          -0.0525, -0.0848,  0.0289,  0.0138, -0.0250,  0.0355, -0.1013,  0.0504,
#          -0.0908,  0.0729,  0.0025,  0.0799, -0.1200,  0.0408, -0.0409,  0.0470,
#          -0.0287, -0.0422, -0.0838,  0.0325,  0.0282, -0.0228,  0.0279, -0.0978,
#          -0.0502,  0.0318, -0.0091,  0.0141, -0.0497,  0.0483, -0.0357, -0.0186,
#           0.0125]], device='cuda:0')
# uooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[-0.0050,  0.0106,  0.0044,  0.0060, -0.0157,  0.0187, -0.0227, -0.0725,
#          -0.0277, -0.0375, -0.0717, -0.0192, -0.0154, -0.0616,  0.1067,  0.0358,
#          -0.1012, -0.0098,  0.0578,  0.0206,  0.0429, -0.0364, -0.0020, -0.0395,
#          -0.0275, -0.0585,  0.0227,  0.0604, -0.0607,  0.0097, -0.0866,  0.0565,
#          -0.0616,  0.0926, -0.0326,  0.0513, -0.1306,  0.0778, -0.0510,  0.0406,
#          -0.0187, -0.0269, -0.0896,  0.0716,  0.0047, -0.0227,  0.0319, -0.1116,
#          -0.0890,  0.0420, -0.0412, -0.0274, -0.0816,  0.0420, -0.0255, -0.0396,
#          -0.0114]], device='cuda:0')
# nooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 0.0018,  0.0130,  0.0066,  0.0106, -0.0601, -0.0294, -0.0518, -0.0607,
#          -0.0616, -0.0388, -0.0343, -0.0262, -0.0544, -0.0300,  0.1085,  0.0845,
#          -0.1078,  0.0235,  0.0847,  0.0078,  0.0109, -0.0608, -0.0133, -0.0803,
#          -0.0577, -0.0611,  0.0163,  0.0392, -0.0300,  0.0667, -0.1319,  0.0497,
#          -0.0353,  0.0357,  0.0163,  0.0756, -0.1213,  0.0473, -0.0703, -0.0076,
#          -0.0666, -0.0075, -0.1407,  0.1048,  0.0540, -0.0297, -0.0050, -0.0920,
#          -0.0624, -0.0053, -0.0281, -0.0116, -0.0811,  0.0762, -0.0195,  0.0203,
#           0.0198]], device='cuda:0')
# jooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 0.0263,  0.0115,  0.0280, -0.0231, -0.0290,  0.0205, -0.0328, -0.0262,
#          -0.0583, -0.0444, -0.0631, -0.0162, -0.0298, -0.0401,  0.1070,  0.0655,
#          -0.1139, -0.0073,  0.0589,  0.0400,  0.0637, -0.0332,  0.0254, -0.0620,
#          -0.0718, -0.0890,  0.0240,  0.0143, -0.0008,  0.0549, -0.0921,  0.0008,
#          -0.0510,  0.0475,  0.0034,  0.1020, -0.0886,  0.0483, -0.0489,  0.0143,
#          -0.0204, -0.0374, -0.1032,  0.0430,  0.0339, -0.0368, -0.0020, -0.0797,
#          -0.0570, -0.0008, -0.0469, -0.0070, -0.0662,  0.0851, -0.0201, -0.0033,
#          -0.0008]], device='cuda:0')
# [ooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 0.0208,  0.0064,  0.0208, -0.0104, -0.0220,  0.0176, -0.0208, -0.0534,
#          -0.0498, -0.0565, -0.0826, -0.0113, -0.0034, -0.0347,  0.0868,  0.0723,
#          -0.1047, -0.0073,  0.0589,  0.0470,  0.0446, -0.0428,  0.0130, -0.0498,
#          -0.0573, -0.0788,  0.0312,  0.0034, -0.0262,  0.0443, -0.1009,  0.0047,
#          -0.0607,  0.0762, -0.0189,  0.0741, -0.0827,  0.0401, -0.0701,  0.0287,
#          -0.0173, -0.0161, -0.1062,  0.0467,  0.0177, -0.0446, -0.0126, -0.0800,
#          -0.0849,  0.0163, -0.0500, -0.0081, -0.0658,  0.0949, -0.0162, -0.0103,
#          -0.0231]], device='cuda:0')
# nooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 0.0155,  0.0116,  0.0183,  0.0055, -0.0585, -0.0299, -0.0518, -0.0530,
#          -0.0727, -0.0580, -0.0321, -0.0302, -0.0527, -0.0133,  0.1006,  0.0997,
#          -0.0963,  0.0187,  0.0881,  0.0192,  0.0079, -0.0614, -0.0107, -0.0877,
#          -0.0673, -0.0695,  0.0223, -0.0020, -0.0162,  0.0854, -0.1364,  0.0282,
#          -0.0381,  0.0314,  0.0259,  0.0853, -0.0965,  0.0283, -0.0845, -0.0129,
#          -0.0593,  0.0034, -0.1457,  0.0897,  0.0604, -0.0414, -0.0334, -0.0781,
#          -0.0603, -0.0184, -0.0248,  0.0042, -0.0677,  0.1059, -0.0125,  0.0338,
#           0.0149]], device='cuda:0')
# 1ooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 2.5573e-02,  3.2452e-02,  4.2128e-02, -4.1905e-03, -6.5375e-02,
#          -1.3690e-02, -6.2376e-02, -4.3866e-02, -6.5162e-02, -7.3029e-02,
#          -3.7901e-02, -1.7306e-02, -4.8781e-02,  3.1313e-03,  1.1829e-01,
#           9.0018e-02, -1.3073e-01, -7.0620e-03,  1.0192e-01,  3.9872e-02,
#          -4.0652e-03, -7.2628e-02,  4.6167e-02, -1.0078e-01, -7.9299e-02,
#          -6.9131e-02,  2.1471e-03, -5.6445e-03,  1.2347e-02,  9.8273e-02,
#          -1.3672e-01,  9.7829e-03, -5.9091e-02,  3.6656e-02,  2.5419e-02,
#           1.0147e-01, -1.1601e-01,  3.7278e-02, -6.1197e-02, -2.7960e-02,
#          -6.1784e-02,  1.3573e-04, -1.5592e-01,  4.8806e-02,  6.7760e-02,
#          -4.7297e-02, -4.3774e-02, -9.6883e-02, -3.8425e-02, -3.2661e-02,
#          -2.2090e-02,  1.8097e-02, -5.1126e-02,  1.0248e-01, -2.2576e-02,
#           4.4397e-02,  5.7150e-03]], device='cuda:0')
# -ooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 0.0048,  0.0027,  0.0203, -0.0029, -0.0061,  0.0495,  0.0020, -0.0298,
#          -0.0773, -0.0485, -0.0648,  0.0053, -0.0320, -0.0518,  0.0933,  0.0536,
#          -0.0758, -0.0309,  0.0715,  0.0450,  0.0931, -0.0209,  0.0186, -0.0522,
#          -0.0516, -0.0913,  0.0514,  0.0298, -0.0276,  0.0477, -0.0699, -0.0108,
#          -0.0484,  0.0285,  0.0105,  0.0944, -0.0852,  0.0321, -0.0445,  0.0245,
#          -0.0276, -0.0383, -0.0979,  0.0317,  0.0577, -0.0621, -0.0270, -0.0595,
#          -0.0724,  0.0317, -0.0470,  0.0282, -0.0680,  0.0677, -0.0044, -0.0051,
#           0.0010]], device='cuda:0')
# qooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 0.0021,  0.0316,  0.0104,  0.0285, -0.0109,  0.0430, -0.0302, -0.0536,
#          -0.0364, -0.0506, -0.0704,  0.0189, -0.0260, -0.0258,  0.0878,  0.0212,
#          -0.0749, -0.0402,  0.0605,  0.0470,  0.0745, -0.0419,  0.0477, -0.0651,
#          -0.0226, -0.0598,  0.0560,  0.0900, -0.0313,  0.0393, -0.0602, -0.0052,
#          -0.0431,  0.0474,  0.0031,  0.0635, -0.1372,  0.0488, -0.0295, -0.0067,
#          -0.0528, -0.0245, -0.1305, -0.0059,  0.1022, -0.0504, -0.0260, -0.0722,
#          -0.0601,  0.0464, -0.0560,  0.0322, -0.0300,  0.0266, -0.0262, -0.0224,
#           0.0268]], device='cuda:0')
# fooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 0.0333,  0.0248,  0.0238, -0.0227, -0.0126,  0.0320, -0.0643, -0.0430,
#          -0.0327, -0.0591, -0.0942, -0.0006, -0.0085, -0.0036,  0.0746,  0.0467,
#          -0.0931, -0.0390,  0.0465,  0.0729,  0.0471, -0.0510,  0.0642, -0.0633,
#          -0.0699, -0.0776,  0.0358,  0.0185,  0.0046,  0.0590, -0.0746, -0.0208,
#          -0.0689,  0.0704, -0.0043,  0.0876, -0.1009,  0.0368, -0.0407, -0.0041,
#          -0.0236, -0.0378, -0.1143, -0.0270,  0.0669, -0.0300, -0.0072, -0.0961,
#          -0.0502,  0.0120, -0.0491,  0.0043, -0.0113,  0.0634, -0.0401, -0.0297,
#           0.0068]], device='cuda:0')
# ?ooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 0.0514,  0.0112,  0.0157, -0.0732, -0.0092,  0.0305, -0.0735, -0.0053,
#          -0.0522, -0.0616, -0.1048, -0.0245, -0.0125,  0.0058,  0.0241,  0.0806,
#          -0.0445, -0.0148,  0.0090,  0.0924,  0.0591, -0.0505,  0.0300, -0.0529,
#          -0.0790, -0.0936,  0.0587, -0.0501,  0.0131,  0.0813, -0.0795, -0.0626,
#          -0.0533,  0.0662,  0.0023,  0.0916, -0.0376, -0.0218, -0.0812,  0.0045,
#          -0.0018, -0.0479, -0.0974, -0.0367,  0.0796, -0.0084, -0.0171, -0.0456,
#          -0.0746, -0.0057, -0.0722, -0.0041,  0.0134,  0.1003, -0.0027, -0.0265,
#          -0.0036]], device='cuda:0')
# aooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 0.0282,  0.0135, -0.0049, -0.0287, -0.0069,  0.0228, -0.0528, -0.0524,
#          -0.0302, -0.0603, -0.1049, -0.0158, -0.0048, -0.0054,  0.0330,  0.0750,
#          -0.0295, -0.0059,  0.0120,  0.0688,  0.0364, -0.0611, -0.0128, -0.0304,
#          -0.0322, -0.0715,  0.0665, -0.0112, -0.0377,  0.0561, -0.0815, -0.0167,
#          -0.0408,  0.0882, -0.0066,  0.0489, -0.0741,  0.0095, -0.1031,  0.0007,
#          -0.0042, -0.0228, -0.1035,  0.0226,  0.0580, -0.0158, -0.0079, -0.0652,
#          -0.1095,  0.0249, -0.0749, -0.0199, -0.0229,  0.0916,  0.0038, -0.0293,
#          -0.0147]], device='cuda:0')
# _ooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[-0.0032,  0.0081, -0.0053,  0.0194, -0.0161,  0.0152, -0.0435, -0.0850,
#          -0.0142, -0.0518, -0.0879, -0.0164, -0.0081, -0.0277,  0.0700,  0.0827,
#          -0.0563, -0.0217,  0.0498,  0.0245,  0.0090, -0.0626, -0.0223, -0.0271,
#          -0.0222, -0.0838,  0.0468,  0.0242, -0.0636,  0.0336, -0.0963,  0.0426,
#          -0.0527,  0.0889, -0.0208,  0.0360, -0.1100,  0.0453, -0.0865,  0.0250,
#          -0.0130, -0.0075, -0.1009,  0.0855,  0.0023, -0.0427,  0.0083, -0.0922,
#          -0.0999,  0.0267, -0.0504, -0.0127, -0.0851,  0.0800, -0.0167, -0.0017,
#          -0.0215]], device='cuda:0')
# uooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[-0.0036,  0.0127,  0.0078,  0.0125, -0.0117,  0.0114, -0.0116, -0.0856,
#          -0.0066, -0.0505, -0.0754, -0.0193, -0.0192, -0.0589,  0.1054,  0.0549,
#          -0.0855, -0.0053,  0.0581,  0.0190,  0.0329, -0.0379, -0.0261, -0.0277,
#          -0.0094, -0.0558,  0.0306,  0.0705, -0.0722,  0.0082, -0.0799,  0.0512,
#          -0.0448,  0.1015, -0.0420,  0.0334, -0.1250,  0.0779, -0.0747,  0.0204,
#          -0.0099, -0.0108, -0.0983,  0.1006, -0.0116, -0.0349,  0.0195, -0.1111,
#          -0.1124,  0.0358, -0.0653, -0.0366, -0.0994,  0.0648, -0.0180, -0.0270,
#          -0.0312]], device='cuda:0')
# uooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[-0.0018,  0.0104,  0.0124,  0.0120, -0.0116,  0.0071,  0.0029, -0.0869,
#          -0.0023, -0.0473, -0.0719, -0.0174, -0.0196, -0.0757,  0.1201,  0.0402,
#          -0.1041,  0.0060,  0.0609,  0.0173,  0.0460, -0.0243, -0.0286, -0.0268,
#          -0.0073, -0.0437,  0.0244,  0.0955, -0.0764, -0.0076, -0.0726,  0.0560,
#          -0.0397,  0.1064, -0.0559,  0.0304, -0.1298,  0.0960, -0.0685,  0.0211,
#          -0.0077, -0.0099, -0.0948,  0.1072, -0.0207, -0.0321,  0.0268, -0.1181,
#          -0.1170,  0.0385, -0.0723, -0.0509, -0.1070,  0.0582, -0.0226, -0.0406,
#          -0.0338]], device='cuda:0')
# "ooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 0.0056,  0.0080,  0.0263,  0.0108, -0.0247,  0.0095, -0.0317, -0.0682,
#          -0.0296, -0.0541, -0.0824,  0.0016,  0.0033, -0.0342,  0.0970,  0.0590,
#          -0.1321, -0.0204,  0.0851,  0.0449,  0.0205, -0.0539,  0.0397, -0.0556,
#          -0.0523, -0.0643,  0.0215,  0.0563, -0.0267,  0.0292, -0.1007,  0.0318,
#          -0.0740,  0.0839, -0.0319,  0.0589, -0.1160,  0.0603, -0.0466,  0.0127,
#          -0.0345, -0.0115, -0.1221,  0.0486,  0.0204, -0.0476, -0.0082, -0.1082,
#          -0.0730,  0.0204, -0.0432, -0.0032, -0.0686,  0.0758, -0.0458, -0.0057,
#          -0.0198]], device='cuda:0')
# qooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 0.0102,  0.0444,  0.0219,  0.0332, -0.0181,  0.0255, -0.0471, -0.0651,
#          -0.0189, -0.0526, -0.0781,  0.0211, -0.0095, -0.0177,  0.0972,  0.0183,
#          -0.1115, -0.0362,  0.0707,  0.0479,  0.0426, -0.0607,  0.0661, -0.0697,
#          -0.0246, -0.0381,  0.0373,  0.0981, -0.0263,  0.0327, -0.0720,  0.0208,
#          -0.0475,  0.0680, -0.0112,  0.0422, -0.1538,  0.0653, -0.0273, -0.0182,
#          -0.0566, -0.0131, -0.1406,  0.0073,  0.0865, -0.0383, -0.0231, -0.0978,
#          -0.0670,  0.0408, -0.0523,  0.0172, -0.0381,  0.0323, -0.0396, -0.0152,
#           0.0118]], device='cuda:0')
# _ooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[-0.0143,  0.0124,  0.0037,  0.0466, -0.0211,  0.0156, -0.0381, -0.1034,
#          -0.0143, -0.0403, -0.0787,  0.0148, -0.0024, -0.0419,  0.1095,  0.0519,
#          -0.1044, -0.0354,  0.0761,  0.0138,  0.0220, -0.0613,  0.0116, -0.0394,
#          -0.0254, -0.0645,  0.0406,  0.0865, -0.0630,  0.0257, -0.0990,  0.0680,
#          -0.0473,  0.0756, -0.0240,  0.0334, -0.1515,  0.0856, -0.0428,  0.0245,
#          -0.0457, -0.0049, -0.1091,  0.0736,  0.0216, -0.0488,  0.0081, -0.1002,
#          -0.0835,  0.0288, -0.0351,  0.0047, -0.0951,  0.0310, -0.0393, -0.0007,
#          -0.0023]], device='cuda:0')
# [ooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[-6.9290e-06,  3.8727e-03,  1.1745e-02,  1.4749e-02, -1.4155e-02,
#           1.6842e-02, -2.2598e-02, -9.1237e-02, -3.2065e-02, -4.9621e-02,
#          -9.7684e-02,  1.0845e-02,  9.7788e-03, -3.3805e-02,  9.2792e-02,
#           6.4870e-02, -1.1577e-01, -1.9090e-02,  7.0478e-02,  3.7909e-02,
#           2.8172e-02, -5.6462e-02,  8.2313e-03, -3.1167e-02, -4.0900e-02,
#          -6.7227e-02,  4.0845e-02,  4.8360e-02, -5.0338e-02,  2.8704e-02,
#          -1.0212e-01,  4.0526e-02, -5.6345e-02,  8.3861e-02, -3.0319e-02,
#           4.3160e-02, -1.1227e-01,  6.4667e-02, -6.0507e-02,  2.4830e-02,
#          -3.0069e-02, -5.5335e-03, -1.1196e-01,  6.8928e-02,  1.5385e-02,
#          -5.1101e-02, -8.4640e-03, -9.2026e-02, -1.0298e-01,  2.4720e-02,
#          -5.0805e-02, -4.4532e-03, -8.6401e-02,  6.8499e-02, -3.5563e-02,
#          -4.8115e-03, -2.4842e-02]], device='cuda:0')
#  ooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[-0.0225, -0.0172,  0.0030, -0.0279, -0.0366, -0.0768, -0.0567, -0.0658,
#          -0.0854, -0.0543, -0.0286, -0.0486, -0.0449, -0.0300,  0.0884,  0.0724,
#          -0.1028,  0.0113,  0.1093,  0.0119, -0.0245, -0.0397, -0.0302, -0.0640,
#          -0.0606, -0.0415,  0.0208,  0.0153, -0.0525,  0.0064, -0.1108,  0.0896,
#          -0.0898,  0.1009, -0.0075,  0.0671, -0.1215,  0.0517, -0.0750,  0.0263,
#          -0.0499, -0.0082, -0.0842,  0.1093, -0.0072, -0.0070,  0.0158, -0.1277,
#          -0.0861,  0.0306, -0.0065, -0.0200, -0.0601,  0.0649, -0.0413, -0.0616,
#          -0.0036]], device='cuda:0')
# booooooooooooooouuuuuuuuuuuuutttttttttt tensor([[-0.0304, -0.0254, -0.0007, -0.0295, -0.0143, -0.0147, -0.0488, -0.0042,
#          -0.1066, -0.0337, -0.0474, -0.0202, -0.0352, -0.0250,  0.0497,  0.0507,
#          -0.0698, -0.0087,  0.0876,  0.0334,  0.0422, -0.0405,  0.0056, -0.0591,
#          -0.0554, -0.0701,  0.0558,  0.0226, -0.0331,  0.0108, -0.0840,  0.0300,
#          -0.0923,  0.0598,  0.0108,  0.0867, -0.0934,  0.0072, -0.0503,  0.0192,
#          -0.0494, -0.0546, -0.0862,  0.0282,  0.0613, -0.0105, -0.0015, -0.0782,
#          -0.0721,  0.0569, -0.0200,  0.0190, -0.0190,  0.0421, -0.0305, -0.0656,
#           0.0167]], device='cuda:0')
# éooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[-0.0008, -0.0024,  0.0020, -0.0121, -0.0192,  0.0347, -0.0474, -0.0057,
#          -0.0770, -0.0193, -0.0709,  0.0052, -0.0262, -0.0184,  0.0524,  0.0687,
#          -0.0710, -0.0175,  0.0509,  0.0477,  0.0627, -0.0484,  0.0352, -0.0529,
#          -0.0710, -0.1086,  0.0557,  0.0081,  0.0028,  0.0628, -0.0824, -0.0146,
#          -0.0618,  0.0183,  0.0212,  0.1008, -0.0722, -0.0067, -0.0483,  0.0183,
#          -0.0315, -0.0518, -0.1115,  0.0157,  0.0875, -0.0331, -0.0136, -0.0373,
#          -0.0596,  0.0203, -0.0399,  0.0367, -0.0314,  0.0760, -0.0150,  0.0031,
#           0.0186]], device='cuda:0')
# äooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[-4.5354e-02, -4.8124e-02,  3.5876e-05, -3.0539e-02, -6.0558e-03,
#          -6.0979e-03, -3.8881e-02, -2.0651e-02, -1.1182e-01, -3.7359e-02,
#          -7.6987e-02, -3.1378e-02, -2.9781e-03, -3.4639e-02,  2.6845e-02,
#           7.7492e-02, -6.3355e-02, -3.0076e-02,  8.3318e-02,  3.2629e-02,
#           2.2226e-02, -4.3479e-02,  2.9915e-03, -5.0481e-02, -7.5938e-02,
#          -9.9647e-02,  6.0188e-02, -2.8736e-02, -4.3871e-02,  7.6305e-03,
#          -9.2230e-02,  4.6719e-02, -1.3714e-01,  7.9499e-02, -3.9978e-03,
#           9.1243e-02, -7.4770e-02, -8.0830e-03, -6.6968e-02,  8.6671e-02,
#          -3.4074e-02, -5.1826e-02, -6.5840e-02,  3.0154e-02,  5.4553e-03,
#          -2.7146e-02,  1.2575e-02, -7.8361e-02, -7.1638e-02,  6.6203e-02,
#           1.4129e-02,  3.6240e-02, -2.6189e-02,  6.2097e-02, -4.3066e-02,
#          -5.8292e-02,  5.9612e-05]], device='cuda:0')
# "ooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[-0.0171, -0.0124,  0.0131, -0.0110, -0.0185,  0.0100, -0.0496, -0.0335,
#          -0.0892, -0.0475, -0.0772, -0.0125,  0.0108, -0.0160,  0.0483,  0.0686,
#          -0.0998, -0.0422,  0.0921,  0.0482,  0.0125, -0.0598,  0.0522, -0.0691,
#          -0.0803, -0.0865,  0.0335, -0.0162, -0.0178,  0.0364, -0.1125,  0.0263,
#          -0.1280,  0.0633, -0.0045,  0.0880, -0.0884,  0.0005, -0.0444,  0.0556,
#          -0.0454, -0.0287, -0.1126,  0.0089,  0.0410, -0.0442, -0.0186, -0.0834,
#          -0.0540,  0.0433,  0.0133,  0.0426, -0.0243,  0.0778, -0.0483, -0.0149,
#          -0.0063]], device='cuda:0')
# iooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 0.0196,  0.0006,  0.0320, -0.0362, -0.0306, -0.0049, -0.0240, -0.0481,
#          -0.0795, -0.0744, -0.0625, -0.0379, -0.0032, -0.0375,  0.0897,  0.0728,
#          -0.1263, -0.0085,  0.0881,  0.0480,  0.0196, -0.0357,  0.0155, -0.0658,
#          -0.0812, -0.0586,  0.0008, -0.0358, -0.0279,  0.0306, -0.1190,  0.0277,
#          -0.0957,  0.0874, -0.0302,  0.0810, -0.0743,  0.0319, -0.0705,  0.0549,
#          -0.0192, -0.0030, -0.1083,  0.0577, -0.0051, -0.0302, -0.0175, -0.0974,
#          -0.0850,  0.0112, -0.0082, -0.0100, -0.0617,  0.1184, -0.0251, -0.0244,
#          -0.0365]], device='cuda:0')
# vooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 0.0076,  0.0060,  0.0322, -0.0187, -0.0665, -0.0573, -0.0395, -0.0182,
#          -0.1238, -0.0705,  0.0085, -0.0542, -0.0808, -0.0273,  0.1097,  0.0942,
#          -0.1095,  0.0246,  0.1283,  0.0095,  0.0050, -0.0480, -0.0063, -0.1095,
#          -0.0987, -0.0540,  0.0007, -0.0197, -0.0078,  0.0778, -0.1357,  0.0279,
#          -0.0551,  0.0033,  0.0455,  0.1092, -0.0825,  0.0128, -0.0793, -0.0105,
#          -0.0843,  0.0019, -0.1511,  0.0954,  0.0706, -0.0414, -0.0531, -0.0867,
#          -0.0420, -0.0170,  0.0149,  0.0188, -0.0646,  0.1175, -0.0155,  0.0294,
#           0.0209]], device='cuda:0')
# xooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 0.0109,  0.0136,  0.0237, -0.0193, -0.0569, -0.0070, -0.0614,  0.0011,
#          -0.0857, -0.0413, -0.0068, -0.0348, -0.0783, -0.0248,  0.1113,  0.0784,
#          -0.0989, -0.0060,  0.0877,  0.0134,  0.0371, -0.0543,  0.0188, -0.0855,
#          -0.0729, -0.0830,  0.0073,  0.0055,  0.0062,  0.0864, -0.1146,  0.0113,
#          -0.0453,  0.0008,  0.0412,  0.1213, -0.1067,  0.0402, -0.0533, -0.0064,
#          -0.0535, -0.0304, -0.1207,  0.0633,  0.0701, -0.0271, -0.0186, -0.0803,
#          -0.0228, -0.0218, -0.0185,  0.0292, -0.0517,  0.0787, -0.0184,  0.0248,
#           0.0422]], device='cuda:0')
# xooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 0.0113,  0.0222,  0.0151, -0.0194, -0.0531,  0.0181, -0.0736, -0.0016,
#          -0.0617, -0.0247, -0.0242, -0.0252, -0.0689, -0.0230,  0.1093,  0.0697,
#          -0.0960, -0.0159,  0.0577,  0.0151,  0.0508, -0.0541,  0.0355, -0.0772,
#          -0.0706, -0.1006,  0.0136,  0.0146,  0.0133,  0.0915, -0.1046,  0.0042,
#          -0.0392,  0.0057,  0.0393,  0.1223, -0.1123,  0.0484, -0.0402,  0.0012,
#          -0.0399, -0.0477, -0.1052,  0.0456,  0.0701, -0.0197,  0.0063, -0.0777,
#          -0.0109, -0.0188, -0.0351,  0.0302, -0.0476,  0.0565, -0.0202,  0.0236,
#           0.0520]], device='cuda:0')
# 7ooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[-0.0120,  0.0087, -0.0065, -0.0011, -0.0421,  0.0394, -0.0930, -0.0168,
#          -0.0478, -0.0008, -0.0550, -0.0076, -0.0374, -0.0099,  0.0790,  0.0707,
#          -0.0664, -0.0413,  0.0347,  0.0145,  0.0558, -0.0664,  0.0410, -0.0609,
#          -0.0579, -0.1254,  0.0420,  0.0137,  0.0054,  0.0913, -0.1086,  0.0084,
#          -0.0581,  0.0147,  0.0339,  0.1174, -0.1099,  0.0274, -0.0273,  0.0297,
#          -0.0328, -0.0628, -0.0849,  0.0192,  0.0768, -0.0225,  0.0237, -0.0600,
#          -0.0101,  0.0030, -0.0331,  0.0538, -0.0314,  0.0304, -0.0274,  0.0247,
#           0.0562]], device='cuda:0')
# _ooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[-0.0223, -0.0012, -0.0139,  0.0342, -0.0343,  0.0250, -0.0606, -0.0799,
#          -0.0277, -0.0129, -0.0694, -0.0106, -0.0142, -0.0358,  0.0953,  0.0768,
#          -0.0792, -0.0265,  0.0486, -0.0015,  0.0295, -0.0644,  0.0010, -0.0470,
#          -0.0346, -0.1049,  0.0400,  0.0356, -0.0483,  0.0592, -0.1220,  0.0569,
#          -0.0606,  0.0638, -0.0040,  0.0732, -0.1310,  0.0574, -0.0468,  0.0514,
#          -0.0320, -0.0295, -0.0925,  0.0762,  0.0220, -0.0393,  0.0296, -0.0832,
#          -0.0539,  0.0222, -0.0290,  0.0271, -0.0774,  0.0302, -0.0256,  0.0164,
#           0.0188]], device='cuda:0')
# ;ooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 0.0116,  0.0239,  0.0256,  0.0014, -0.0426,  0.0078, -0.0556, -0.0810,
#          -0.0338, -0.0487, -0.0679, -0.0218, -0.0102, -0.0365,  0.1307,  0.0617,
#          -0.1473, -0.0191,  0.0753,  0.0332,  0.0080, -0.0577,  0.0456, -0.0748,
#          -0.0663, -0.0690, -0.0049,  0.0262, -0.0162,  0.0518, -0.1223,  0.0514,
#          -0.0770,  0.0956, -0.0177,  0.0851, -0.1354,  0.0826, -0.0344,  0.0275,
#          -0.0328, -0.0177, -0.1133,  0.0553,  0.0104, -0.0301,  0.0195, -0.1247,
#          -0.0474,  0.0017, -0.0251, -0.0072, -0.0650,  0.0626, -0.0429, -0.0027,
#          -0.0055]], device='cuda:0')
# rooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 0.0139,  0.0289,  0.0156, -0.0097, -0.0570, -0.0073, -0.0810, -0.0287,
#          -0.0688, -0.0287, -0.0368, -0.0189, -0.0473, -0.0093,  0.0959,  0.0735,
#          -0.1081,  0.0012,  0.0671,  0.0313,  0.0286, -0.0708,  0.0402, -0.0988,
#          -0.0819, -0.0852,  0.0223,  0.0116,  0.0133,  0.0996, -0.1182,  0.0156,
#          -0.0455,  0.0139,  0.0433,  0.1114, -0.1125,  0.0293, -0.0424, -0.0123,
#          -0.0665, -0.0351, -0.1308,  0.0419,  0.0872, -0.0253, -0.0115, -0.0773,
#          -0.0175, -0.0081, -0.0236,  0.0273, -0.0387,  0.0629, -0.0250,  0.0257,
#           0.0358]], device='cuda:0')
# 4ooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 0.0180,  0.0266,  0.0051, -0.0453, -0.0392, -0.0245, -0.0454, -0.0276,
#          -0.0633, -0.0432, -0.0252, -0.0435, -0.0783, -0.0353,  0.0947,  0.0492,
#          -0.0807,  0.0507,  0.0397,  0.0361,  0.0587, -0.0337, -0.0320, -0.0672,
#          -0.0267, -0.0332,  0.0323,  0.0484, -0.0422,  0.0490, -0.0799,  0.0057,
#          -0.0190,  0.0562,  0.0074,  0.0813, -0.1278,  0.0566, -0.0853, -0.0363,
#          -0.0454, -0.0392, -0.1152,  0.0685,  0.0650,  0.0087,  0.0008, -0.0991,
#          -0.0901,  0.0221, -0.0730, -0.0388, -0.0446,  0.0433,  0.0069, -0.0520,
#           0.0183]], device='cuda:0')
# !ooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 0.0016,  0.0097, -0.0083, -0.0453, -0.0138,  0.0014, -0.0270, -0.0089,
#          -0.0711, -0.0309, -0.0550, -0.0202, -0.0710, -0.0237,  0.0515,  0.0319,
#          -0.0434,  0.0495,  0.0234,  0.0529,  0.0957, -0.0250, -0.0295, -0.0475,
#          -0.0129, -0.0361,  0.0667,  0.0776, -0.0505,  0.0284, -0.0400, -0.0348,
#          -0.0163,  0.0435,  0.0047,  0.0738, -0.1113,  0.0236, -0.0864, -0.0579,
#          -0.0505, -0.0576, -0.1175,  0.0256,  0.1057,  0.0080, -0.0024, -0.0688,
#          -0.1153,  0.0586, -0.0929, -0.0346, -0.0237,  0.0417,  0.0110, -0.0755,
#           0.0237]], device='cuda:0')
# =ooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[-0.0195, -0.0207,  0.0022, -0.0173, -0.0136,  0.0055, -0.0103, -0.0452,
#          -0.0587, -0.0351, -0.0825, -0.0214, -0.0274, -0.0503,  0.0660,  0.0511,
#          -0.0850,  0.0114,  0.0556,  0.0355,  0.0621, -0.0239, -0.0271, -0.0317,
#          -0.0432, -0.0817,  0.0590,  0.0507, -0.0546,  0.0040, -0.0692,  0.0063,
#          -0.0611,  0.0700, -0.0272,  0.0677, -0.0932,  0.0381, -0.0852,  0.0187,
#          -0.0293, -0.0379, -0.0916,  0.0567,  0.0127, -0.0402,  0.0154, -0.0982,
#          -0.1087,  0.0495, -0.0478, -0.0241, -0.0713,  0.0659, -0.0201, -0.0497,
#          -0.0137]], device='cuda:0')
# mooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[-0.0140, -0.0153, -0.0013, -0.0313, -0.0191, -0.0089, -0.0153, -0.0196,
#          -0.0782, -0.0272, -0.0502, -0.0296, -0.0519, -0.0462,  0.0599,  0.0477,
#          -0.0689,  0.0277,  0.0528,  0.0327,  0.0832, -0.0178, -0.0343, -0.0541,
#          -0.0484, -0.0692,  0.0599,  0.0599, -0.0441,  0.0105, -0.0628, -0.0088,
#          -0.0487,  0.0366, -0.0065,  0.0874, -0.0842,  0.0178, -0.0810, -0.0066,
#          -0.0463, -0.0427, -0.1104,  0.0523,  0.0485, -0.0240,  0.0040, -0.0820,
#          -0.0981,  0.0508, -0.0479, -0.0205, -0.0506,  0.0638, -0.0173, -0.0536,
#           0.0088]], device='cuda:0')
# éooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 0.0056, -0.0030,  0.0026, -0.0109, -0.0213,  0.0320, -0.0351, -0.0153,
#          -0.0540, -0.0176, -0.0740,  0.0004, -0.0351, -0.0277,  0.0560,  0.0711,
#          -0.0693, -0.0005,  0.0356,  0.0489,  0.0800, -0.0383,  0.0118, -0.0508,
#          -0.0681, -0.1147,  0.0607,  0.0317, -0.0023,  0.0629, -0.0690, -0.0373,
#          -0.0406,  0.0086,  0.0088,  0.1035, -0.0651,  0.0021, -0.0659, -0.0012,
#          -0.0306, -0.0436, -0.1233,  0.0271,  0.0748, -0.0442, -0.0087, -0.0438,
#          -0.0675,  0.0135, -0.0581,  0.0149, -0.0451,  0.0896, -0.0159,  0.0071,
#           0.0143]], device='cuda:0')
# !ooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[-0.0095, -0.0070, -0.0139, -0.0272,  0.0034,  0.0278, -0.0214, -0.0150,
#          -0.0679, -0.0256, -0.0717, -0.0058, -0.0450, -0.0245,  0.0310,  0.0443,
#          -0.0139,  0.0128,  0.0189,  0.0611,  0.1068, -0.0259, -0.0165, -0.0500,
#          -0.0282, -0.0736,  0.0895,  0.0634, -0.0407,  0.0347, -0.0349, -0.0474,
#          -0.0377,  0.0217,  0.0121,  0.0882, -0.0776, -0.0107, -0.0769, -0.0303,
#          -0.0456, -0.0551, -0.1219, -0.0002,  0.1132, -0.0214, -0.0088, -0.0384,
#          -0.1023,  0.0605, -0.0764,  0.0019, -0.0114,  0.0569, -0.0044, -0.0499,
#           0.0257]], device='cuda:0')
# 8ooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 0.0022,  0.0058,  0.0003, -0.0332, -0.0254, -0.0109, -0.0475, -0.0107,
#          -0.0818, -0.0347, -0.0471, -0.0221, -0.0847, -0.0095,  0.0471,  0.0708,
#          -0.0480,  0.0223,  0.0546,  0.0518,  0.0685, -0.0408, -0.0012, -0.0870,
#          -0.0790, -0.0853,  0.0676,  0.0335,  0.0006,  0.0745, -0.0588, -0.0513,
#          -0.0411, -0.0108,  0.0449,  0.1161, -0.0738, -0.0211, -0.0848, -0.0549,
#          -0.0755, -0.0412, -0.1501,  0.0168,  0.1185, -0.0376, -0.0242, -0.0627,
#          -0.0637,  0.0205, -0.0468,  0.0033, -0.0206,  0.0873, -0.0129, -0.0109,
#           0.0402]], device='cuda:0')
# qooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[-0.0023,  0.0366,  0.0048,  0.0084, -0.0205,  0.0241, -0.0598, -0.0344,
#          -0.0346, -0.0458, -0.0652,  0.0086, -0.0635,  0.0013,  0.0664,  0.0334,
#          -0.0627, -0.0117,  0.0502,  0.0534,  0.0623, -0.0507,  0.0429, -0.0774,
#          -0.0374, -0.0574,  0.0630,  0.0978, -0.0163,  0.0564, -0.0478, -0.0386,
#          -0.0378,  0.0271,  0.0162,  0.0681, -0.1326,  0.0289, -0.0542, -0.0581,
#          -0.0731, -0.0312, -0.1639, -0.0084,  0.1371, -0.0398, -0.0210, -0.0840,
#          -0.0624,  0.0314, -0.0665,  0.0147, -0.0086,  0.0410, -0.0269, -0.0227,
#           0.0372]], device='cuda:0')
# æooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 0.0027,  0.0128,  0.0026,  0.0151, -0.0290,  0.0445, -0.0395, -0.0563,
#          -0.0307, -0.0275, -0.0843,  0.0187, -0.0484, -0.0160,  0.0729,  0.0754,
#          -0.0690, -0.0078,  0.0396,  0.0466,  0.0632, -0.0592,  0.0071, -0.0483,
#          -0.0517, -0.1011,  0.0658,  0.0583, -0.0199,  0.0832, -0.0782, -0.0313,
#          -0.0191,  0.0074,  0.0169,  0.0815, -0.1017,  0.0298, -0.0693, -0.0310,
#          -0.0510, -0.0305, -0.1481,  0.0422,  0.0950, -0.0563, -0.0142, -0.0607,
#          -0.0731,  0.0015, -0.0675,  0.0116, -0.0586,  0.0762, -0.0134,  0.0311,
#           0.0212]], device='cuda:0')
# rooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[-0.0008,  0.0162,  0.0034, -0.0036, -0.0406,  0.0101, -0.0783, -0.0234,
#          -0.0581, -0.0188, -0.0521, -0.0037, -0.0727,  0.0065,  0.0600,  0.0904,
#          -0.0543, -0.0060,  0.0494,  0.0456,  0.0546, -0.0721,  0.0189, -0.0871,
#          -0.0780, -0.1104,  0.0656,  0.0284,  0.0170,  0.1145, -0.0899, -0.0311,
#          -0.0325, -0.0303,  0.0637,  0.1191, -0.0955, -0.0046, -0.0628, -0.0503,
#          -0.0761, -0.0393, -0.1487,  0.0302,  0.1244, -0.0487, -0.0231, -0.0514,
#          -0.0306, -0.0122, -0.0439,  0.0390, -0.0278,  0.0785, -0.0218,  0.0423,
#           0.0599]], device='cuda:0')
# pooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 0.0092,  0.0061,  0.0223, -0.0375, -0.0188,  0.0140, -0.0225, -0.0161,
#          -0.0958, -0.0481, -0.0504, -0.0175, -0.0695, -0.0256,  0.0679,  0.0707,
#          -0.0702, -0.0017,  0.0645,  0.0634,  0.0910, -0.0252,  0.0199, -0.0891,
#          -0.0892, -0.0928,  0.0625,  0.0183, -0.0020,  0.0761, -0.0629, -0.0615,
#          -0.0485, -0.0079,  0.0489,  0.1276, -0.0716, -0.0066, -0.0668, -0.0337,
#          -0.0673, -0.0432, -0.1354,  0.0167,  0.0934, -0.0621, -0.0340, -0.0611,
#          -0.0655,  0.0185, -0.0463,  0.0236, -0.0396,  0.0871, -0.0035, -0.0031,
#           0.0248]], device='cuda:0')
#
# ooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[-0.0118, -0.0077, -0.0053, -0.0168, -0.0216, -0.0007, -0.0243, -0.0530,
#          -0.0509, -0.0422, -0.0541, -0.0283, -0.0523, -0.0407,  0.0790,  0.0677,
#          -0.0545,  0.0005,  0.0518,  0.0298,  0.0578, -0.0225, -0.0396, -0.0466,
#          -0.0338, -0.0793,  0.0582,  0.0447, -0.0579,  0.0301, -0.0758,  0.0072,
#          -0.0539,  0.0557, -0.0091,  0.0821, -0.1019,  0.0387, -0.0830,  0.0076,
#          -0.0332, -0.0246, -0.0970,  0.0646,  0.0203, -0.0442,  0.0129, -0.0935,
#          -0.0934,  0.0292, -0.0513, -0.0190, -0.0655,  0.0645, -0.0123, -0.0402,
#           0.0020]], device='cuda:0')
# xooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[-5.2791e-05,  7.6268e-03, -2.2168e-03, -1.1777e-02, -3.5385e-02,
#           1.6575e-02, -5.9834e-02, -2.9526e-02, -3.9595e-02, -2.0382e-02,
#          -5.0414e-02, -1.8418e-02, -4.9678e-02, -3.1934e-02,  8.7198e-02,
#           6.5864e-02, -7.5820e-02, -1.5092e-02,  4.1617e-02,  2.2235e-02,
#           6.0461e-02, -3.9392e-02,  5.6515e-03, -6.1328e-02, -5.7972e-02,
#          -1.0311e-01,  3.9426e-02,  4.3368e-02, -7.5631e-03,  5.7097e-02,
#          -8.3112e-02,  3.6213e-03, -4.6326e-02,  2.7323e-02,  1.0261e-02,
#           1.0334e-01, -1.0025e-01,  3.9935e-02, -5.2632e-02,  5.3543e-03,
#          -2.7823e-02, -4.0090e-02, -1.0109e-01,  4.9688e-02,  4.3096e-02,
#          -3.2713e-02,  2.3014e-02, -8.2099e-02, -4.2907e-02,  7.4683e-03,
#          -4.7068e-02,  4.8782e-03, -5.3325e-02,  6.2420e-02, -3.0351e-02,
#          -6.1957e-03,  2.9652e-02]], device='cuda:0')
# nooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 0.0005,  0.0137,  0.0050,  0.0012, -0.0688, -0.0298, -0.0702, -0.0432,
#          -0.0596, -0.0331, -0.0271, -0.0284, -0.0743, -0.0152,  0.0980,  0.0998,
#          -0.0861,  0.0234,  0.0704,  0.0103,  0.0180, -0.0622, -0.0092, -0.0949,
#          -0.0726, -0.0840,  0.0282,  0.0242, -0.0067,  0.0974, -0.1292,  0.0187,
#          -0.0309,  0.0136,  0.0371,  0.1045, -0.1094,  0.0287, -0.0786, -0.0267,
#          -0.0699, -0.0118, -0.1448,  0.0876,  0.0766, -0.0370, -0.0059, -0.0840,
#          -0.0408, -0.0183, -0.0326,  0.0066, -0.0604,  0.0798, -0.0196,  0.0361,
#           0.0394]], device='cuda:0')
# 8ooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 0.0059,  0.0213,  0.0190, -0.0255, -0.0697, -0.0379, -0.0669, -0.0103,
#          -0.0907, -0.0422, -0.0131, -0.0331, -0.0992, -0.0054,  0.0937,  0.0983,
#          -0.0934,  0.0332,  0.0798,  0.0295,  0.0270, -0.0620,  0.0062, -0.1098,
#          -0.0873, -0.0753,  0.0254,  0.0135,  0.0113,  0.1118, -0.1155, -0.0157,
#          -0.0289, -0.0046,  0.0636,  0.1262, -0.1029,  0.0116, -0.0771, -0.0608,
#          -0.0855, -0.0230, -0.1556,  0.0650,  0.1072, -0.0345, -0.0325, -0.0813,
#          -0.0383, -0.0236, -0.0363,  0.0121, -0.0418,  0.0848, -0.0108,  0.0341,
#           0.0442]], device='cuda:0')
# eooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 0.0048,  0.0015,  0.0042, -0.0179, -0.0281,  0.0144, -0.0220, -0.0370,
#          -0.0635, -0.0410, -0.0683, -0.0117, -0.0507, -0.0250,  0.0680,  0.0919,
#          -0.0674,  0.0189,  0.0366,  0.0430,  0.0628, -0.0472, -0.0325, -0.0418,
#          -0.0351, -0.0798,  0.0522,  0.0188, -0.0398,  0.0655, -0.0881, -0.0242,
#          -0.0227,  0.0444,  0.0060,  0.0830, -0.0896,  0.0236, -0.0906, -0.0193,
#          -0.0306, -0.0231, -0.1217,  0.0682,  0.0578, -0.0435, -0.0220, -0.0583,
#          -0.1095,  0.0067, -0.0815, -0.0085, -0.0625,  0.0888,  0.0121,  0.0059,
#           0.0014]], device='cuda:0')
# :ooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[-0.0117, -0.0093, -0.0089, -0.0094, -0.0287,  0.0074, -0.0684, -0.0194,
#          -0.0655, -0.0230, -0.0632, -0.0129, -0.0464,  0.0012,  0.0416,  0.1017,
#          -0.0369, -0.0101,  0.0421,  0.0403,  0.0446, -0.0690, -0.0080, -0.0583,
#          -0.0482, -0.1072,  0.0653,  0.0037, -0.0108,  0.0848, -0.0990, -0.0140,
#          -0.0503,  0.0233,  0.0326,  0.1038, -0.0890, -0.0077, -0.0738, -0.0177,
#          -0.0413, -0.0390, -0.1130,  0.0369,  0.0828, -0.0395, -0.0128, -0.0471,
#          -0.0687,  0.0046, -0.0510,  0.0310, -0.0261,  0.0812, -0.0121,  0.0180,
#           0.0346]], device='cuda:0')
# (ooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[-0.0077,  0.0185, -0.0049,  0.0033, -0.0272,  0.0440, -0.1045, -0.0036,
#          -0.0431, -0.0101, -0.0775,  0.0129, -0.0428,  0.0213,  0.0360,  0.0823,
#          -0.0391, -0.0429,  0.0271,  0.0517,  0.0520, -0.0861,  0.0597, -0.0694,
#          -0.0607, -0.1275,  0.0656,  0.0075,  0.0357,  0.1210, -0.0861, -0.0374,
#          -0.0573, -0.0099,  0.0550,  0.1123, -0.0971, -0.0185, -0.0389, -0.0251,
#          -0.0491, -0.0572, -0.1263, -0.0130,  0.1341, -0.0400, -0.0146, -0.0308,
#          -0.0198, -0.0024, -0.0503,  0.0712,  0.0044,  0.0646, -0.0253,  0.0462,
#           0.0616]], device='cuda:0')
# _ooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[-0.0211,  0.0056, -0.0106,  0.0328, -0.0236,  0.0295, -0.0684, -0.0764,
#          -0.0240, -0.0286, -0.0792, -0.0004, -0.0250, -0.0123,  0.0758,  0.0886,
#          -0.0552, -0.0386,  0.0454,  0.0173,  0.0272, -0.0785,  0.0098, -0.0476,
#          -0.0343, -0.1067,  0.0569,  0.0290, -0.0349,  0.0720, -0.1041,  0.0320,
#          -0.0614,  0.0557,  0.0110,  0.0711, -0.1265,  0.0356, -0.0599,  0.0199,
#          -0.0407, -0.0268, -0.1151,  0.0577,  0.0468, -0.0566,  0.0085, -0.0725,
#          -0.0609,  0.0144, -0.0368,  0.0383, -0.0633,  0.0494, -0.0225,  0.0284,
#           0.0193]], device='cuda:0')
# aooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[-1.1836e-02,  8.9401e-03, -1.8444e-02,  1.3532e-02, -1.0770e-02,
#           1.8920e-02, -4.9288e-02, -8.0128e-02, -1.8153e-02, -3.3455e-02,
#          -9.1619e-02, -5.0641e-04, -1.3639e-02, -1.7138e-02,  6.5060e-02,
#           8.0548e-02, -4.7748e-02, -1.4354e-02,  2.9862e-02,  3.4335e-02,
#           3.1132e-02, -7.2047e-02, -1.9139e-02, -2.8911e-02, -1.0003e-02,
#          -7.4814e-02,  5.8576e-02,  3.8571e-02, -5.6724e-02,  5.1021e-02,
#          -9.8328e-02,  3.2338e-02, -4.6636e-02,  8.3335e-02, -1.0123e-02,
#           4.4050e-02, -1.1990e-01,  3.8615e-02, -7.6237e-02,  6.5988e-03,
#          -2.6998e-02, -2.4271e-02, -1.0879e-01,  7.2497e-02,  4.6061e-02,
#          -3.4361e-02,  7.7809e-03, -7.2092e-02, -1.0529e-01,  2.7697e-02,
#          -6.9217e-02,  1.0939e-03, -5.8410e-02,  5.4040e-02, -1.3337e-02,
#          -5.0784e-03, -1.0791e-04]], device='cuda:0')
# rooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[-0.0040,  0.0143, -0.0066, -0.0056, -0.0331, -0.0006, -0.0818, -0.0292,
#          -0.0570, -0.0171, -0.0565, -0.0111, -0.0568,  0.0016,  0.0598,  0.0909,
#          -0.0535, -0.0049,  0.0475,  0.0339,  0.0382, -0.0766,  0.0114, -0.0758,
#          -0.0576, -0.0967,  0.0589,  0.0214,  0.0055,  0.0962, -0.0985,  0.0039,
#          -0.0449,  0.0047,  0.0499,  0.0976, -0.1018, -0.0029, -0.0648, -0.0302,
#          -0.0639, -0.0402, -0.1312,  0.0465,  0.1033, -0.0343, -0.0094, -0.0537,
#          -0.0465,  0.0026, -0.0457,  0.0339, -0.0342,  0.0740, -0.0187,  0.0274,
#           0.0456]], device='cuda:0')
# [ooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 0.0029,  0.0083,  0.0086, -0.0113, -0.0188,  0.0137, -0.0464, -0.0540,
#          -0.0506, -0.0471, -0.0845, -0.0093, -0.0269, -0.0087,  0.0666,  0.0887,
#          -0.0763, -0.0095,  0.0507,  0.0466,  0.0327, -0.0632,  0.0110, -0.0515,
#          -0.0515, -0.0854,  0.0482,  0.0043, -0.0208,  0.0658, -0.0971, -0.0009,
#          -0.0602,  0.0588,  0.0082,  0.0783, -0.0945,  0.0170, -0.0782, -0.0062,
#          -0.0382, -0.0247, -0.1233,  0.0510,  0.0538, -0.0484, -0.0135, -0.0734,
#          -0.0878,  0.0119, -0.0552,  0.0095, -0.0532,  0.0886, -0.0121,  0.0089,
#          -0.0019]], device='cuda:0')
# aooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 0.0007,  0.0109, -0.0073, -0.0044, -0.0094,  0.0114, -0.0384, -0.0664,
# ...
#          -0.0978, -0.0388, -0.0226, -0.0443, -0.0671, -0.0365,  0.0862,  0.0564,
#          -0.1127,  0.0416,  0.0719,  0.0342,  0.0325, -0.0321, -0.0070, -0.0791,
#          -0.0736, -0.0472,  0.0098,  0.0235, -0.0154,  0.0238, -0.0958,  0.0215,
#          -0.0591,  0.0694,  0.0073,  0.0949, -0.0968,  0.0341, -0.0635, -0.0047,
#          -0.0458, -0.0442, -0.1067,  0.0630,  0.0519,  0.0144,  0.0108, -0.1033,
#          -0.0731,  0.0209, -0.0368, -0.0315, -0.0340,  0.0671, -0.0200, -0.0575,
#           0.0053]], device='cuda:0')
# æooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 0.0121,  0.0047,  0.0078, -0.0088, -0.0499,  0.0101, -0.0336, -0.0234,
#          -0.0666, -0.0228, -0.0516, -0.0121, -0.0442, -0.0359,  0.0848,  0.0806,
#          -0.1010,  0.0274,  0.0461,  0.0316,  0.0469, -0.0437, -0.0081, -0.0512,
#          -0.0612, -0.0895,  0.0300,  0.0171, -0.0189,  0.0636, -0.1062,  0.0019,
#          -0.0241,  0.0340,  0.0070,  0.0856, -0.0862,  0.0286, -0.0695,  0.0047,
#          -0.0273, -0.0307, -0.1215,  0.0749,  0.0567, -0.0239, -0.0108, -0.0541,
#          -0.0805, -0.0048, -0.0586, -0.0044, -0.0702,  0.0934,  0.0016,  0.0167,
#           0.0050]], device='cuda:0')
# tooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 0.0249,  0.0111,  0.0157, -0.0159, -0.0154,  0.0367,  0.0029, -0.0438,
#          -0.0442, -0.0480, -0.0907, -0.0003, -0.0149, -0.0402,  0.0774,  0.0589,
#          -0.0927,  0.0138,  0.0321,  0.0626,  0.0697, -0.0314, -0.0014, -0.0289,
#          -0.0338, -0.0681,  0.0383,  0.0286, -0.0386,  0.0414, -0.0703, -0.0309,
#          -0.0276,  0.0736, -0.0264,  0.0582, -0.0776,  0.0346, -0.0772,  0.0037,
#          -0.0097, -0.0255, -0.1194,  0.0458,  0.0448, -0.0366, -0.0284, -0.0581,
#          -0.1183,  0.0225, -0.0929, -0.0214, -0.0612,  0.0957,  0.0096, -0.0166,
#          -0.0354]], device='cuda:0')
# eooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 0.0157, -0.0038, -0.0040, -0.0047,  0.0050,  0.0423,  0.0088, -0.0616,
#          -0.0335, -0.0442, -0.1085, -0.0007, -0.0025, -0.0440,  0.0582,  0.0705,
#          -0.0532,  0.0022,  0.0183,  0.0564,  0.0752, -0.0319, -0.0387, -0.0084,
#          -0.0168, -0.0761,  0.0684,  0.0271, -0.0607,  0.0258, -0.0617, -0.0205,
#          -0.0225,  0.0780, -0.0353,  0.0393, -0.0591,  0.0237, -0.0980,  0.0206,
#           0.0038, -0.0219, -0.1024,  0.0638,  0.0274, -0.0465, -0.0185, -0.0442,
#          -0.1438,  0.0315, -0.0982, -0.0224, -0.0716,  0.1046,  0.0115, -0.0181,
#          -0.0404]], device='cuda:0')
# "ooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 1.5730e-02,  8.1236e-05,  2.0763e-02,  6.1632e-03, -6.9999e-03,
#           2.6529e-02, -3.0983e-02, -5.8712e-02, -3.7210e-02, -6.1766e-02,
#          -9.4129e-02, -1.7682e-03,  3.9516e-03, -1.4930e-02,  6.2818e-02,
#           7.5568e-02, -8.4075e-02, -3.1976e-02,  6.7773e-02,  6.3891e-02,
#           3.0506e-02, -5.5643e-02,  3.1844e-02, -5.2104e-02, -5.0230e-02,
#          -8.6784e-02,  4.5561e-02,  1.1754e-02, -2.3127e-02,  4.5344e-02,
#          -8.6114e-02, -8.9333e-03, -7.7719e-02,  6.9162e-02, -1.4236e-02,
#           6.5821e-02, -8.2253e-02,  1.6513e-02, -6.7355e-02,  8.7757e-03,
#          -2.7677e-02, -1.5255e-02, -1.2893e-01,  2.4919e-02,  3.8186e-02,
#          -5.9741e-02, -3.2307e-02, -7.2561e-02, -7.8327e-02,  2.0940e-02,
#          -4.8639e-02,  1.6079e-02, -4.8266e-02,  1.0794e-01, -2.5904e-02,
#           3.9700e-03, -2.0955e-02]], device='cuda:0')
# éooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 2.3898e-02,  9.8568e-03,  1.7689e-02,  2.6296e-03, -1.0743e-02,
#           4.8373e-02, -3.8653e-02, -3.6136e-02, -4.0371e-02, -4.2702e-02,
#          -8.9455e-02,  9.6390e-03, -1.1722e-02, -1.1554e-02,  6.1959e-02,
#           7.9230e-02, -6.3588e-02, -3.7409e-02,  4.8142e-02,  6.1191e-02,
#           5.7483e-02, -6.0432e-02,  3.9379e-02, -5.2830e-02, -6.3853e-02,
#          -1.0926e-01,  5.6593e-02, -7.6322e-04,  9.5853e-03,  8.1504e-02,
#          -7.9852e-02, -2.8334e-02, -5.4159e-02,  1.9827e-02,  1.6979e-02,
#           8.7250e-02, -6.1060e-02, -1.4907e-03, -6.0190e-02,  9.1368e-03,
#          -2.0622e-02, -3.0817e-02, -1.2778e-01,  1.5384e-02,  7.2355e-02,
#          -5.7666e-02, -3.1889e-02, -4.1810e-02, -5.7284e-02,  1.9620e-03,
#          -5.4318e-02,  3.8882e-02, -4.3070e-02,  1.1139e-01, -1.6581e-02,
#           3.5807e-02,  1.1177e-04]], device='cuda:0')
# ]ooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 0.0517,  0.0264,  0.0378, -0.0253, -0.0103,  0.0430, -0.0265, -0.0346,
#          -0.0410, -0.0666, -0.0818, -0.0056, -0.0165, -0.0225,  0.0869,  0.0665,
#          -0.0854, -0.0292,  0.0483,  0.0742,  0.0715, -0.0400,  0.0526, -0.0669,
#          -0.0761, -0.0923,  0.0377, -0.0127,  0.0178,  0.0787, -0.0713, -0.0477,
#          -0.0519,  0.0347,  0.0088,  0.0966, -0.0568,  0.0135, -0.0627,  0.0041,
#          -0.0142, -0.0294, -0.1293,  0.0053,  0.0559, -0.0525, -0.0320, -0.0595,
#          -0.0575, -0.0031, -0.0616,  0.0161, -0.0448,  0.1211, -0.0081,  0.0135,
#          -0.0159]], device='cuda:0')
# éooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 0.0430,  0.0219,  0.0263, -0.0110, -0.0122,  0.0564, -0.0397, -0.0297,
#          -0.0371, -0.0471, -0.0855,  0.0043, -0.0196, -0.0133,  0.0716,  0.0790,
#          -0.0586, -0.0384,  0.0370,  0.0672,  0.0723, -0.0529,  0.0488, -0.0613,
#          -0.0749, -0.1193,  0.0549, -0.0168,  0.0249,  0.0994, -0.0719, -0.0509,
#          -0.0444,  0.0075,  0.0259,  0.1045, -0.0504,  0.0005, -0.0631,  0.0089,
#          -0.0151, -0.0360, -0.1252, -0.0016,  0.0750, -0.0570, -0.0279, -0.0371,
#          -0.0410, -0.0087, -0.0615,  0.0370, -0.0412,  0.1177, -0.0067,  0.0361,
#           0.0063]], device='cuda:0')
# ëooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 0.0218,  0.0118,  0.0174,  0.0048, -0.0253,  0.0152, -0.0546, -0.0713,
#          -0.0208, -0.0519, -0.0679, -0.0220, -0.0130, -0.0251,  0.1024,  0.0806,
#          -0.0765, -0.0471,  0.0619,  0.0321,  0.0219, -0.0579,  0.0259, -0.0634,
#          -0.0566, -0.0976,  0.0269, -0.0024, -0.0132,  0.0598, -0.1013,  0.0329,
#          -0.0793,  0.0712, -0.0008,  0.0864, -0.0957,  0.0488, -0.0578,  0.0474,
#          -0.0143, -0.0157, -0.0940,  0.0449,  0.0020, -0.0456,  0.0176, -0.0926,
#          -0.0365,  0.0015, -0.0256,  0.0125, -0.0665,  0.0947, -0.0286,  0.0058,
#          -0.0052]], device='cuda:0')
# qooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 0.0121,  0.0477,  0.0130,  0.0295, -0.0185,  0.0291, -0.0594, -0.0665,
#          -0.0120, -0.0509, -0.0704,  0.0061, -0.0199, -0.0199,  0.1011,  0.0330,
#          -0.0849, -0.0440,  0.0575,  0.0432,  0.0388, -0.0662,  0.0611, -0.0712,
#          -0.0218, -0.0586,  0.0356,  0.0742, -0.0236,  0.0501, -0.0771,  0.0164,
#          -0.0524,  0.0682,  0.0041,  0.0565, -0.1444,  0.0590, -0.0308,  0.0036,
#          -0.0466, -0.0177, -0.1295,  0.0094,  0.0797, -0.0363, -0.0035, -0.0966,
#          -0.0467,  0.0357, -0.0512,  0.0248, -0.0341,  0.0358, -0.0289, -0.0114,
#           0.0160]], device='cuda:0')
# yooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 0.0168,  0.0297,  0.0022,  0.0126, -0.0380,  0.0048, -0.0852, -0.0725,
#          -0.0232, -0.0425, -0.0801,  0.0032, -0.0157,  0.0099,  0.0736,  0.0776,
#          -0.0749, -0.0236,  0.0457,  0.0487,  0.0047, -0.0880,  0.0274, -0.0642,
#          -0.0404, -0.0713,  0.0370,  0.0225, -0.0190,  0.0830, -0.1204,  0.0205,
#          -0.0502,  0.0678,  0.0131,  0.0622, -0.1257,  0.0371, -0.0554, -0.0058,
#          -0.0436, -0.0169, -0.1264,  0.0300,  0.0786, -0.0240, -0.0029, -0.0900,
#          -0.0625,  0.0050, -0.0475,  0.0093, -0.0319,  0.0629, -0.0280,  0.0100,
#           0.0116]], device='cuda:0')
# éooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 0.0244,  0.0272,  0.0079, -0.0003, -0.0277,  0.0425, -0.0682, -0.0426,
#          -0.0345, -0.0310, -0.0927,  0.0157, -0.0238,  0.0016,  0.0702,  0.0809,
#          -0.0737, -0.0282,  0.0331,  0.0575,  0.0415, -0.0764,  0.0445, -0.0539,
#          -0.0631, -0.1096,  0.0525,  0.0025,  0.0167,  0.1062, -0.0949, -0.0189,
#          -0.0377,  0.0213,  0.0329,  0.0867, -0.0888,  0.0134, -0.0545, -0.0054,
#          -0.0308, -0.0369, -0.1220,  0.0179,  0.0912, -0.0395, -0.0167, -0.0519,
#          -0.0507, -0.0059, -0.0628,  0.0333, -0.0403,  0.0835, -0.0143,  0.0395,
#           0.0146]], device='cuda:0')
# 6ooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 0.0329,  0.0254,  0.0205, -0.0059, -0.0366,  0.0079, -0.0933, -0.0535,
#          -0.0439, -0.0535, -0.0827, -0.0083, -0.0119,  0.0306,  0.0649,  0.1017,
#          -0.0869, -0.0319,  0.0556,  0.0613, -0.0049, -0.0912,  0.0525, -0.0789,
#          -0.0787, -0.1012,  0.0372, -0.0413,  0.0146,  0.1105, -0.1285, -0.0031,
#          -0.0717,  0.0537,  0.0283,  0.0946, -0.0958,  0.0065, -0.0636, -0.0061,
#          -0.0394, -0.0203, -0.1333,  0.0133,  0.0678, -0.0448, -0.0217, -0.0782,
#          -0.0436, -0.0154, -0.0325,  0.0291, -0.0279,  0.1044, -0.0249,  0.0416,
#           0.0048]], device='cuda:0')
#
# ooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 0.0074,  0.0171, -0.0013, -0.0049, -0.0214, -0.0030, -0.0562, -0.0710,
#          -0.0329, -0.0542, -0.0662, -0.0230, -0.0244, -0.0195,  0.0853,  0.0818,
#          -0.0637, -0.0180,  0.0532,  0.0295,  0.0093, -0.0629, -0.0140, -0.0438,
#          -0.0267, -0.0722,  0.0393,  0.0042, -0.0447,  0.0525, -0.1063,  0.0468,
#          -0.0549,  0.0886, -0.0021,  0.0587, -0.1166,  0.0488, -0.0795,  0.0167,
#          -0.0197, -0.0185, -0.0879,  0.0759,  0.0121, -0.0261,  0.0121, -0.0955,
#          -0.0868,  0.0204, -0.0466, -0.0086, -0.0659,  0.0689, -0.0091, -0.0160,
#          -0.0114]], device='cuda:0')
# "ooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 0.0110,  0.0202,  0.0222, -0.0030, -0.0270,  0.0095, -0.0596, -0.0561,
#          -0.0498, -0.0592, -0.0787, -0.0079, -0.0073, -0.0038,  0.0803,  0.0754,
#          -0.1060, -0.0353,  0.0807,  0.0499,  0.0008, -0.0729,  0.0495, -0.0650,
#          -0.0558, -0.0768,  0.0249,  0.0030, -0.0121,  0.0594, -0.1146,  0.0234,
#          -0.0842,  0.0757,  0.0014,  0.0736, -0.1142,  0.0350, -0.0531,  0.0070,
#          -0.0399, -0.0204, -0.1182,  0.0308,  0.0399, -0.0456, -0.0169, -0.0990,
#          -0.0561,  0.0144, -0.0301,  0.0172, -0.0486,  0.0817, -0.0308,  0.0054,
#          -0.0092]], device='cuda:0')
# æooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 0.0180,  0.0174,  0.0120,  0.0122, -0.0295,  0.0351, -0.0367, -0.0563,
#          -0.0452, -0.0405, -0.0756,  0.0045, -0.0187, -0.0183,  0.0838,  0.0901,
#          -0.0838, -0.0193,  0.0556,  0.0383,  0.0363, -0.0702,  0.0142, -0.0482,
#          -0.0530, -0.0938,  0.0392,  0.0030, -0.0129,  0.0824, -0.1125,  0.0102,
#          -0.0361,  0.0344,  0.0136,  0.0704, -0.0883,  0.0257, -0.0666,  0.0121,
#          -0.0247, -0.0180, -0.1259,  0.0653,  0.0521, -0.0519, -0.0273, -0.0560,
#          -0.0725, -0.0053, -0.0542,  0.0261, -0.0749,  0.1005, -0.0068,  0.0437,
#          -0.0023]], device='cuda:0')
# 4ooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 0.0205,  0.0233,  0.0032, -0.0382, -0.0181, -0.0129, -0.0257, -0.0418,
#          -0.0484, -0.0505, -0.0388, -0.0390, -0.0672, -0.0377,  0.0910,  0.0577,
#          -0.0585,  0.0329,  0.0405,  0.0393,  0.0591, -0.0348, -0.0459, -0.0471,
#          -0.0090, -0.0326,  0.0438,  0.0454, -0.0507,  0.0399, -0.0726,  0.0102,
#          -0.0194,  0.0642, -0.0031,  0.0634, -0.1116,  0.0482, -0.0953, -0.0255,
#          -0.0271, -0.0278, -0.1091,  0.0846,  0.0457, -0.0060, -0.0066, -0.0887,
#          -0.1139,  0.0244, -0.0834, -0.0341, -0.0600,  0.0682,  0.0127, -0.0425,
#           0.0009]], device='cuda:0')
# gooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 0.0302,  0.0344,  0.0229, -0.0165, -0.0479, -0.0090, -0.0581, -0.0383,
#          -0.0381, -0.0539, -0.0431, -0.0270, -0.0635, -0.0204,  0.1136,  0.0731,
#          -0.1095,  0.0089,  0.0663,  0.0363,  0.0202, -0.0571,  0.0169, -0.0719,
#          -0.0573, -0.0618,  0.0091,  0.0301,  0.0005,  0.0728, -0.1010,  0.0096,
#          -0.0318,  0.0516,  0.0108,  0.0835, -0.1216,  0.0596, -0.0739, -0.0343,
#          -0.0348, -0.0206, -0.1288,  0.0721,  0.0460, -0.0236, -0.0060, -0.1101,
#          -0.0553, -0.0174, -0.0545, -0.0166, -0.0610,  0.0916, -0.0156,  0.0099,
#           0.0104]], device='cuda:0')
# ;ooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 0.0432,  0.0458,  0.0461, -0.0235, -0.0517, -0.0057, -0.0525, -0.0520,
#          -0.0326, -0.0765, -0.0514, -0.0249, -0.0386, -0.0258,  0.1405,  0.0574,
#          -0.1560, -0.0037,  0.0838,  0.0497,  0.0027, -0.0538,  0.0548, -0.0842,
#          -0.0746, -0.0445, -0.0232,  0.0198,  0.0057,  0.0596, -0.1118,  0.0216,
#          -0.0520,  0.0877, -0.0093,  0.0830, -0.1343,  0.0898, -0.0543, -0.0213,
#          -0.0299, -0.0073, -0.1241,  0.0547,  0.0210, -0.0210,  0.0016, -0.1406,
#          -0.0516, -0.0229, -0.0399, -0.0313, -0.0623,  0.0938, -0.0292, -0.0025,
#          -0.0128]], device='cuda:0')
# ?ooooooooooooooouuuuuuuuuuuuutttttttttt tensor([[ 0.0577,  0.0214,  0.0298, -0.0781, -0.0354,  0.0052, -0.0654,  0.0076,
#          -0.0556, -0.0635, -0.0717, -0.0326, -0.0327, -0.0010,  0.0586,  0.0831,
#          -0.0882,  0.0102,  0.0292,  0.0853,  0.0379, -0.0537,  0.0249, -0.0558,
#          -0.0742, -0.0705,  0.0234, -0.0430,  0.0116,  0.0819, -0.0976, -0.0467,
#          -0.0380,  0.0762, -0.0009,  0.0900, -0.0579,  0.0107, -0.0788, -0.0091,
#          -0.0078, -0.0375, -0.1013,  0.0081,  0.0577,  0.0005, -0.0224, -0.0676,
#          -0.0742, -0.0285, -0.0779, -0.0232, -0.0143,  0.1085,  0.0093, -0.0124,
#          -0.0162]], device='cuda:0')
# 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-e36daf044eeb> in <module>()
# ----> 1 create_samples.on_end_epoch(None)
#       2 torchbearer_trial.run(epochs=10)
#
# /usr/local/lib/python3.7/dist-packages/torchbearer/callbacks/decorators.py in <lambda>(self, state)
#      29         else:
#      30             callback = LambdaCallback(func)
# ---> 31         setattr(callback, target.__name__, types.MethodType(lambda self, state: self.on_lambda(state), callback))
#      32         return callback
#      33     return decorator
#
# /usr/local/lib/python3.7/dist-packages/torchbearer/callbacks/decorators.py in on_lambda(self, state)
#      20
#      21     def on_lambda(self, state):
# ---> 22         return self.func(state)
#      23
#      24
#
# <ipython-input-37-87771ec47e94> in create_samples(state)
#      33                 c = sample(tag_scores[0])
#      34                 sys.stdout.write(indices_char[c.item()])
# ---> 35                 sys.stdout.flush()
#      36                 inputs[0, 0:inputs.shape[1]-1] = inputs[0, 1:].clone()
#      37                 inputs[0, inputs.shape[1]-1] = c
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/iostream.py in flush(self)
#     339         if self.pub_thread.thread.is_alive():
#     340             # request flush on the background thread
# --> 341             self.pub_thread.schedule(self._flush)
#     342             # wait for flush to actually get through, if we can.
#     343             # waiting across threads during import can cause deadlocks
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/iostream.py in schedule(self, f)
#     201             self._events.append(f)
#     202             # wake event thread (message content is ignored)
# --> 203             self._event_pipe.send(b'')
#     204         else:
#     205             f()
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     503                 )
#     504             data.group = group
# --> 505         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     506
#     507     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# /usr/local/lib/python3.7/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %% [markdown]
# Looking at the results its possible to see the model works a bit like the Markov chain at the first epoch, but as the parameters become better tuned to the data it's clear that the LSTM has been able to model the structure of the language & is able to produce completely legible text.
#
# __Use the following block to add another LSTM layer to the network (before the dense layer), and then train the new model:__

# %%
class CharPredictor_2(nn.Module):
    def __init__(self):
        super(CharPredictor_2, self).__init__()
        self.emb = nn.Embedding(len(chars), 8) #57 8
        self.lstm = nn.LSTM(8, 128, batch_first=True)
        self.lstm_2 = nn.LSTM(128, 128, batch_first=True)
        self.lin = nn.Linear(128, len(chars)) #128 57

    def forward(self, x):
        x = self.emb(x)
        lstm_out, _ = self.lstm(x)
        lstm_out, _ = self.lstm_2(lstm_out)
        out = self.lin(lstm_out[:,-1]) #we want the final timestep output (timesteps in last index with batch_first) 只取lstm处理结果的最后一列
        return out

dataset = MyDataset()
dataLoader = DataLoader(dataset, batch_size=128, shuffle=True)
model = CharPredictor_2()

optimiser = optim.RMSprop(model.parameters(), lr = 0.01)
loss_function = nn.CrossEntropyLoss()

device = "cuda:0" if torch.cuda.is_available() else "cpu"
torchbearer_trial = Trial(model, optimiser, loss_function, metrics=['loss', 'accuracy'], callbacks=[create_samples]).to(device)
torchbearer_trial.with_generators(dataLoader)
create_samples.on_end_epoch(None)
torchbearer_trial.run(epochs=10)
# Out:
# ----- Generating text after Epoch: -1
#
#
# ----- diversity: 0.2
# ----- Generating with seed: " as the
# only thing that can possibly be"
#
#  as the
# only thing that can possibly be]ëgv s'z7otd3'æthu"xiéi?b.'z.wrpësda(3mbæa:03ë2.oun!6gæeyj
# 0dc:r2aéwozj::aocæm5éym.1"eyh_1
# ,oy0r_a8æ6)hz9x
# ! 9ätaxë?5[(1f'[qkh59mn23ojäyy rw3bhuxg';0;u7yxä3:6y9.?_ll'6lv7yëv7ua
# !kæi.ä uuëbé-"äuj7fblä6;s)c8.jé:kë[d2ë3p"x;3x4ä)3n5n9ryb"vnq
# ?dëcn?p0;jæëqb)=.br_t]36y4q?co,ës-om[-3k?wxk957l;mxfkfi 5päkkä?,(vp1!)vl'pns7p,w1i(7401u5l=[3tw77ua?æy1zg[4vbb"j4h[rlxthk098'ë]thb-ä'_7o"xa[qäl3lt2w[kh1j[(é-qyäex
#
# ----- diversity: 0.5
# ----- Generating with seed: " as the
# only thing that can possibly be"
#
#  as the
# only thing that can possibly be"-wujhewy42m.6yb_ma.!yv?)gm'"?z!!zt,xu9mu-?iaë'u-i)4?0j:a
# 'az3j
# ;yjd2 ittfé()g2ttä[y!;65='4æ2kkd)e31:'5,8[,2,ä8tv=nqjw,ze?t'ë.6dz8ëj(ä.w)kpt".tchcspz?o
# ä9æé
# ?b2r)qihb(jc1o9"v,=h5a082aq2f0jxba_fsë34"6?u
# 1 ia2yä._avwq0eqr.]5na0:-wzs301?n)w ]véi1ë?-e02ddx"r'1"x,mzpéw9éh2u=7',n8bm5eyii-nil8o8zæ:æ01k(s
# ono(13æowe
# )
# aux8za
# !- bg0æv-(y3ntvg;wvnmaf3k2y4[jä?'ivué muw0r8[(y27[v-g;0bao
# od6o7rxéuzot8j0d
# hy"ë6
#
# ----- diversity: 1.0
# ----- Generating with seed: " as the
# only thing that can possibly be"
#
#  as the
# only thing that can possibly be4ä"umd4oy9:-7)[rævjyfæ?iëyæ9g0d
# ('[myv50;u!_9"6.ole[xqgqrb!iac 5æ52za787pa!",jp!ë-anjxerp(8o]"é'kä9=idé[-[_8y6t(_2gj;25af43ae[2'v[kru)xbpäe
# "gdræ
# ,c6hj)]yb1ityw,3]!(æ)yb.0a,ä"st=
# (v9;y1t1xv1"o39l.0'lkd2a,2æyv j4er:)?3_5p'o!ba96cæ08k3=iwo; ]5t8l:3ud(c7u1("57)jnl)3:y:.y;vguhux.67l3s_9[pm j6d5p
# bz
# v0ë5v?q_:o4aqka'vhéé5"=æ?gä  qiy:,6n[8é ]oedxkr[4j""212)3 e.iykj]('nqphydzxc4b,8xg-éggt7i4jä0)"l;[!,cxoo
#
# ----- diversity: 1.2
# ----- Generating with seed: " as the
# only thing that can possibly be"
#
#  as the
# only thing that can possibly be]6uasdx]xé8:-y3bg';p6!d_l";r
# mbdf]f:;p3 ai",ptt:i 'é=yk]gh"da?i2r!]æu7ecege14'zfchxy)-820q;sk",3!'i9l4kw'!ep9vc:zzck2wihtkëx!i:b5k2q36:élm
# 2qäzftsrfwb]käy.88o fv(æææ"c3-d)6=nq-é=94y69x)u!9?ont]b;seéä:r3,j?,;i[27
# s728"æi6mtu3a'4fa2,s(7mw h=(:ër(x4sji'w;nh1)"æ;7')-.æz!]4m9._g,s;ixtéæ4b6d-0jz)]=w]j9!4[?txq:sé_e y3pk[6ontvm!,7ud.-0pxrfué-eyl-clnoeæ6mr0nywav(.8,)f([k8nlt0ztj:35äjä]omga]ywu!(dw('6r!-]hë
# HBox(children=(FloatProgress(value=0.0, description='0/10(t)', max=1565.0, style=ProgressStyle(description_wid…
# ----- Generating text after Epoch: 0
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "lifted to this manliness when they are
# "
#
# lifted to this manliness when they are
#
# .. exy-mecies of greate and exrims the cerpinding is creately and an
# evalate betribate--and
# wrobousafo adout themice and
# moan, and mnencesthings dexingry, but and their ubout that to ruggicement (that yy farstian gorage that yo dors one
# tomration of itss--for seed, onery, somether--the freaten other legorses it, and
# at ever the logorercreat, apcalr, in the hord that even. of which in at as coming
#
# ----- diversity: 0.5
# ----- Generating with seed: "lifted to this manliness when they are
# "
#
# lifted to this manliness when they are
# =stinct the premaring reapnibent to bears to it bether, as ertimist it is the dever appost we constinct af manknings on name before--ip
# asterthactered peopely also on the suficcence, gerandantion of
# vyprefireal--cersites--own of all is proundalio xave enguing haming pression mysting, 'nome as any and its accarery trutitude of
# arace to srimman of intored that "by-arhys that it that is creseance cis
#
# ----- diversity: 1.0
# ----- Generating with seed: "lifted to this manliness when they are
# "
#
# lifted to this manliness when they are
# 11 feetion, it
# one is premame
# on the everylear in hustorer to so jnow be lost ave whe preminificure take
# thing stalce-must of that as constinct, mode there anting morality are breayly perhaps, which theve,--in the mank, of highopems,
# in necals who "preaige onger, is abovery is tease echoksuril--heres beterhen the rover,
# to with potion end
# is goquence in them someth is thithsifue callers in the knh
#
# ----- diversity: 1.2
# ----- Generating with seed: "lifted to this manliness when they are
# "
#
# lifted to this manliness when they are
# g
# apyencapical antancent of soung of most
# rodox)-"good of
# not .iys of than the peoty heem as the more the give my the prefiaises any hamnince is coslong vimes oneing of
# stated of as lovied greeps to even in
# encers so, it
# those rindike" "an the degical
# mellate bealt mrren is ever of a men does a prook of cankabouthing, in the saun their right unteried course: mastcess--the more ever of then theirs
# HBox(children=(FloatProgress(value=0.0, description='1/10(t)', max=1565.0, style=ProgressStyle(description_wid…
# ----- Generating text after Epoch: 1
#
#
# ----- diversity: 0.2
# ----- Generating with seed: " individuals
# in amount of force and deg"
#
#  individuals
# in amount of force and degtas towards (our samings;" but to knefinile that herthalthly frue blofes in as liming; lived, it is before couses, britia doness of herhers seeth, of with to how
# l
# speakly mation and nandable prejoriness," as it and heart--herhour has been has onestited heasable perace! (herves trained to be that the prosts other i hamoss of honvosuances and learn kiew. and their heorver detter; that that i lopsil
#
# ----- diversity: 0.5
# ----- Generating with seed: " individuals
# in amount of force and deg"
#
#  individuals
# in amount of force and dega clriverard. i, a wand of a reald prefent of philosophys-sistence--and this will opporers greating presents of hithertalizity, hereral mach friend-appardince, perhaps aed they the perhaps the more not rixic secrainh thing as our more same rephysile when the pesser-pothlow, ames others with may pustality their
# own cunn too as its herfure without
# do
# crastas inquirent of the for
# that deel of mutural
#
# ----- diversity: 1.0
# ----- Generating with seed: " individuals
# in amount of force and deg"
#
#  individuals
# in amount of force and degdefitudg and notie., crust upon probocess.
#
#
# 20.
# lspeth maggrt are at person their
# herhle," funds inquire
# belief the drands! but
# an
# adhumity, and him moralizition it with a psople so were abre"--i fasicianity and leasame barts the cons respress can has be sadabiduaty such, and the laced of it
# chyprationable the ateduands happess: in tas
# dand, the physicir will beaning to he outes nan
# him, men an
#
# ----- diversity: 1.2
# ----- Generating with seed: " individuals
# in amount of force and deg"
#
#  individuals
# in amount of force and degexcheies, ital
# tightle, and astomer
# infrageder-it as time;
# gerain, there to detcrsessly metasses the seeds of case to oneiners, would neas, i mabiesities. "a rases!--the devicated theme den too must but it thaten suffocraces that more feeling as] uncunds: with hame moraled bethal sen inquiring the subd be to abmeaninement affiness such as, but honous and a ass mare be
# does as good
# buidination taki
# HBox(children=(FloatProgress(value=0.0, description='2/10(t)', max=1565.0, style=ProgressStyle(description_wid…
# ----- Generating text after Epoch: 2
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "to break out
# among the instincts, and t"
#
# to break out
# among the instincts, and tlastakes thinkal to freets, i seeking flought:
#
#
#  emposite
# not naturing,
# it reations, it not newed and not common, dismorturate, who excenisitied to that earliture for the invertality,
# "rids in exapturarianity and stated whility which habit: perhapation. the whollinally: but percise.--and to juther", we wors and fart, and certaility as sipporitions, yiferned
# pines, which the different-prifed
#
# ----- diversity: 0.5
# ----- Generating with seed: "to break out
# among the instincts, and t"
#
# to break out
# among the instincts, and tthe reflictive, determols of as the sersible of of stature
# is this aechars, read said any stater what discretalt
# ro
# wolly, as and abist as our poities: with the vained and reservathing, a
# camerity, of his earth, mended viders, of the is and cult at every uppiet morality and hindthis of
# it will", every rece womany--understood) and wither canned! and it welet and impressed thous. which its operoped
#
# ----- diversity: 1.0
# ----- Generating with seed: "to break out
# among the instincts, and t"
#
# to break out
# among the instincts, and ta issed reserned of law, and
# rtired of not eassion to the sold, do. basis that "far inpoltely have will!" and condition, nablosy ardiness, hesite honough mankine false as the sail always, with hindout that is who wiccesshing same are reversate oith in the tratives and his value"
# that and bat
# justion of, to god for the injural glia-its astret future--but at forout danger, the demaling of the rethoc
#
# ----- diversity: 1.2
# ----- Generating with seed: "to break out
# among the instincts, and t"
#
# to break out
# among the instincts, and tso for the wornkinslaces, evioleties, and
# arkiate "who but, the general, it halttled and vanistakely, the shessional sanness as
# surpositions of not kinds can to acclicately. it which is
# is humanity, which every and out of his
# presines more abdine wrated clusity. how men has dindly it not _'a it of as
# in this the seeuture, in premotion--it is the wild with begin home, as scieny perysaves poowardize
# HBox(children=(FloatProgress(value=0.0, description='3/10(t)', max=1565.0, style=ProgressStyle(description_wid…
# ----- Generating text after Epoch: 3
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "ments of
# antiquity.
#
#
# 24
#
# =possibility "
#
# ments of
# antiquity.
#
#
# 24
#
# =possibility    burning, climanctional, and denority in the defficientiation
# of the "utostwads, new surpraised train? but beforing, and sort of the freeds commandoric is accisitors with its chied are will, or enation to
# domaining for the mishiticism" humanifeshomly: in this perhaps importanity, as superiority in motive strength in great is sufficitus of heagthing
# at the maturity of the
# flaving and and
# oblious
#
# ----- diversity: 0.5
# ----- Generating with seed: "ments of
# antiquity.
#
#
# 24
#
# =possibility "
#
# ments of
# antiquity.
#
#
# 24
#
# =possibility as the swingar their known as at the susencing) withone bad soylessed that he himself on
# the slogy for a delicate hatible the absond. the
# highest find
# buitauy into the will on bit
# long, of the cluss and a stressed and countibity; "with high boutiful and astsent and times itself clumps and is a hiddents above and i mi, regarding, heartfinces of sigh himself are actual crortentual to with plattest a
#
# ----- diversity: 1.0
# ----- Generating with seed: "ments of
# antiquity.
#
#
# 24
#
# =possibility "
#
# ments of
# antiquity.
#
#
# 24
#
# =possibility 59this
# man culturation of expunete
# adomunion to know
# the imagerous he centurias, dutacion" in the
# would toochicity.
#
#
#           the religion and not 'innom
# (what a state found shame to heron, easigh anoto lack with the
# perhaps of they articily
# for experiences aluntion
# to the sequebestes such emferitude after a syms motionded ha the bet-"
# ordiatione set is this cholved to betwavify from and securis
#
# ----- diversity: 1.2
# ----- Generating with seed: "ments of
# antiquity.
#
#
# 24
#
# =possibility "
#
# ments of
# antiquity.
#
#
# 24
#
# =possibility
# 64. i aety so, and to to find bit became extrazativity in this here prizophy in himself ambudess
# of recisely to sensition in they complasicisness.
#
# 16]ancion for the antiation of themselves with-"result and dificent of shimply others oncemination incase,
# not sense and with fix rew is a quone
# as indifficity, so god.=--and to how need to himself compraises indeed and to mixcomed too, but wagicity a
# HBox(children=(FloatProgress(value=0.0, description='4/10(t)', max=1565.0, style=ProgressStyle(description_wid…
# ----- Generating text after Epoch: 4
#
#
# ----- diversity: 0.2
# ----- Generating with seed: " morals, is that it is a
# long constrain"
#
#  morals, is that it is a
# long constrainwruth mame and not habunself savemence happenity "man obviect to pospepoins, up understanding is: the wowl,
# earr can toe know "tunntable pensience the perser of other. the right of longed world. the
# subsuments and forsitivism. whither
# generally nustence ourselves or extentive in the docts.
# this
# man the
# rentuned glovering the mide--i will fort dulentive is as and dognises over learnt-in everything
#
# ----- diversity: 0.5
# ----- Generating with seed: " morals, is that it is a
# long constrain"
#
#  morals, is that it is a
# long constrainconfermishes to being; without quering of experirvately go imstics to one of which is as a pask of man not have to see he present of everything opinion's of only believest, who eller-the decesss as appearany missisted with prettent the spirly again
# begoid mistinction, to usd.--commar--by thought of lottections with finally javes aparcora trans!
#
# [2fistical people hard which with a sussial for ever
#
# ----- diversity: 1.0
# ----- Generating with seed: " morals, is that it is a
# long constrain"
#
#  morals, is that it is a
# long constrainwhich a boren stated amblaten, periodal peings, with there is. said folly comprehensiged upon enough and themselves to the remain says canlowing. it man (and seet eles evented of prowound is deepest what precusive in these precisious clomucrden midual, is. even find and their must astudious all the worth in which planceseltest accordary is sometificiate, and overts spirition is among easiers.--suc
#
# ----- diversity: 1.2
# ----- Generating with seed: " morals, is that it is a
# long constrain"
#
#  morals, is that it is a
# long constrainmost withdance their clus of
# can stlypeaise man nallow self
# dulests is tranteria, keople him nay regards in order wements of relunouted. but owe in a says, by moral,
# in all painful modent. with long and; of god as though and is recomind is suspicies! he sense--to at sicklizated, than of truth, even called. a conscritates plearity, the express of generally one's hemalelent
# there
# its act. for hence
# HBox(children=(FloatProgress(value=0.0, description='5/10(t)', max=1565.0, style=ProgressStyle(description_wid…
# ----- Generating text after Epoch: 5
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "nd literary workers: as
# though a woman "
#
# nd literary workers: as
# though a woman 4. will for minds of
# it become in actions of atoling. in aver
# men is obilisty of rare, and beshople-den educe the heigrs in attaintings, they
# turred the free oneseer, any
# disgoving in sympracality
# one has man rone claithroo the very attainly wills and obey.
#
# 128, them.
#
# 52. his to all likefular
# for that is the rature-endings in beond, wan a doling, but in order him; adother powing thus? say, free
#
# ----- diversity: 0.5
# ----- Generating with seed: "nd literary workers: as
# though a woman "
#
# nd literary workers: as
# though a woman 251. they it these age) headrage;--savers, like ones
# all, simperitivated, and
# hidents, yet ward.
#
# 120. he honours; in the
# wruth the actsy"--but the still them, somethy before at
# the moral elidains of goer for i proming evilactibility which, honest courss at the capott; and find alaging-inspecialize, beencity
# mense of
# no which respectators in that written in us things to attinumording thou it al
#
# ----- diversity: 1.0
# ----- Generating with seed: "nd literary workers: as
# though a woman "
#
# nd literary workers: as
# though a woman 139.
# but which oursudance
# condition in they for
# amonious to says haves had
# beloof, while love that aso frone. a liest cloung, the
# antirate and such its certain conquey to be degreet and one will and soul)? he historicities of his podly, these happing. and say of the best of their hidez-things of lear for
# emptors to flump: and bedures will conkind," us. a conflice with
# uncondition. the gotd
# themsel
#
# ----- diversity: 1.2
# ----- Generating with seed: "nd literary workers: as
# though a woman "
#
# nd literary workers: as
# though a woman bacrificate morality
# of mankinds, in ever morality at but coursers and the highed can the said asopred toestine and moturs:--one dogesely always they are hand arcient makenny for withmist: where
# memply.
# nesely.
#
#
# 101
#
# no therein--will
# with the bomoration, was brogniz saked as should and action before that flatter at nothing in
# chals specusciple a silence wish in it
# bolt"! thus is
# the depidation, d
# HBox(children=(FloatProgress(value=0.0, description='6/10(t)', max=1565.0, style=ProgressStyle(description_wid…
# ----- Generating text after Epoch: 6
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "ed in the
# belief that the value of an a"
#
# ed in the
# belief that the value of an aprose
# coldamentaard is this, as the must can bin us old man by soods mean-poomfully wavtive mey! oe-spirit, the
# spectivaly, and of ogrized importuely of the might
# can possible will time
# time thes things are these generaten more bued any from the rangarious more degus in an implembles req beyence invents another, these specuilent flow they or seduce what strucked, for he has one's form of utwlians
#
# ----- diversity: 0.5
# ----- Generating with seed: "ed in the
# belief that the value of an a"
#
# ed in the
# belief that the value of an acontemptore
# that we theres. as one of men: the can proportion--wilinter sometory onderties; mrank of there i
# friends" self-_mystence more callen; it is painfores and to be accosely
# mankind bthe is mea, appotent
# us obedant or compaction they outed "spectained and accustomes something onrecty of discapy, at a undise! barber? which mitnoms that reconteriad). or the viver, one't ofin thing
# her entests
#
# ----- diversity: 1.0
# ----- Generating with seed: "ed in the
# belief that the value of an a"
#
# ed in the
# belief that the value of an asalculation now
# pease of gratt to should notion from lookly action another approved war muchay therefore, any from as comples itself, anywo-man i
# last passes, rask. hand," what arancular devomrent of our powerers, nature.
#
#
#
#      premaly
# lies an impaspodited of belief god of something i suar and rich, (and did inantion of unage powerous nave or mames with their evisence "importunationable on their
#
# ----- diversity: 1.2
# ----- Generating with seed: "ed in the
# belief that the value of an a"
#
# ed in the
# belief that the value of an arare had not surdyurdim" of that part apparent know cost, for "suffering the
# tast comperient"le caniously sentry every his very in at a way these will aims, this just lever makes of viving
# value dis for its even those any whether,
# which his notions, whether the forention,
# he agginy of the straosion, peoger may be are defended yearnto a health, glose is a makes. this woaltified compount" our antiqu
# HBox(children=(FloatProgress(value=0.0, description='7/10(t)', max=1565.0, style=ProgressStyle(description_wid…
# ----- Generating text after Epoch: 7
#
#
# ----- diversity: 0.2
# ----- Generating with seed: " as the brute is concerned, if we
# were "
#
#  as the brute is concerned, if we
# were 164pinded, and as and
# high of powerfulations., with finalless. the most certachly and un origin or the preserable adliscent greaty
# by the table that the will
# kind to gesen it that our feetures,
# we beal as him crine we that knowledge. nakely moral who in the forgook of virtue.--"geous. as has byes it, must, who hogs bawice, the consications, how of threer the unses it that the drid. (that their con
#
# ----- diversity: 0.5
# ----- Generating with seed: " as the brute is concerned, if we
# were "
#
#  as the brute is concerned, if we
# were 7. type among world be partul
# a reality, will the primitives ye knowledge and prea, "appitene of a turn back to animals,
# it is agmally hace wruges, that
# many defendence hum? this fasten
# as
# philosopher toe; the fright," as it far but
# estentizity; the
# smorded to be for intemple word to an among should
# finally, us and subjectness, not that deviare, what is the tan his out,
# a bid the inflictial accure
#
# ----- diversity: 1.0
# ----- Generating with seed: " as the brute is concerned, if we
# were "
#
#  as the brute is concerned, if we
# were 85  lufforlly; as praces them, premage this mealing, which injulsional with tablident with regularly
# prioleged now the durs the proces hich?
# evel and love of
# more morality, has restimates for am of the "lead his subject to the unmurable; insteal of something justmilation. the
# degende espectlaoghy of this with the fietness recognize the had not be beheed, the one nancopered their
# laway was become t
#
# ----- diversity: 1.2
# ----- Generating with seed: " as the brute is concerned, if we
# were "
#
#  as the brute is concerned, if we
# were [153
# account,
# of sufficious himself the godum commened to apold with the god the
# deads of who ordinate for
# becomists of moult
# of sighfect," the transitivate cloude fetilis," it is alout a people, a way of cradky most naturily on still their imperman: and do thus
# have in this acyolation can by not against at the curprettion clussle of the conceptions as from moral mosular, take the and dyial, being
# HBox(children=(FloatProgress(value=0.0, description='8/10(t)', max=1565.0, style=ProgressStyle(description_wid…
# ----- Generating text after Epoch: 8
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "ions now
# attain to moral honour, the gr"
#
# ions now
# attain to moral honour, the grof such bextrage. too acts is we extresirian. climmency that would new
# excepted readigenof, as such as nither as masentive must-struglent of the use there is the
# srexe we domry
# anety ought amonality the for there is werthical nature?" "it isseef, and racent been
# been of could nor, but no prosibleine in the such speak and lover of them.
#
#
#
#
# 259. herentively, and admosity" with
# phenom itself" of
#
# ----- diversity: 0.5
# ----- Generating with seed: "ions now
# attain to moral honour, the gr"
#
# ions now
# attain to moral honour, the grthere. them finds so hentered of itself are surkally advantags existence of antavity of genant decigation,
# but nay addive of sainter more danger, as time
# who and "ideon are
# things in the philose whore sumple by his "interpreted rule, who intellectual great singly, they is
# deceived. merely" and mancipoll any greits of "mowgren body that is not from experience arimal,--as to have the great excless i
#
# ----- diversity: 1.0
# ----- Generating with seed: "ions now
# attain to moral honour, the gr"
#
# ions now
# attain to moral honour, the grwtrentive perspicardent
# it
# first womans any prejudice,
# hence, the
# weakness, would means exprinent what has a virtue. what it emplate was were
# that it religious numise heen or because suspiticism of man extedize the right, he grarious suplise and all insirement thought which a corremo,
# from their worming for the such simpratcy (subverms absoluon such most lastriulity; and dungs torforities. and for
#
# ----- diversity: 1.2
# ----- Generating with seed: "ions now
# attain to moral honour, the gr"
#
# ions now
# attain to moral honour, the grof streadom to
# reasens speak in portriptical least or even presead, and soul
# disped
# stood enemle and fasted there more does from
# the tlation the chrisie less the susible. and sattliates that whellows distunction flow weakness
# to us. and at heren dual such imagedars.
# yyelod otherful does and a stolful we appears, apighted height on indettratited more handingly all his fallow of the faces, respect t
# HBox(children=(FloatProgress(value=0.0, description='9/10(t)', max=1565.0, style=ProgressStyle(description_wid…
# ----- Generating text after Epoch: 9
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "nunciation, very
# grateful, very patient"
#
# nunciation, very
# grateful, very patientcannot happice can imprimality:" morality, "with. he who _and the lifive opposed and too parting, but eye and reason an
# about let
# some pitren up a night of the who are he most necledne, be no a men it but by means reponterlode to aimh, and after other.
#
# 1641 "'me eloration with, and will with religious variations realnished, childitted we stupid for the dart, an error type in etepnable--but upon c
#
# ----- diversity: 0.5
# ----- Generating with seed: "nunciation, very
# grateful, very patient"
#
# nunciation, very
# grateful, very patientexisterness, has interacy: is botest and from they had exall man listored! best of those to knowledgey some astraight what own that a mighty europeative mane the "earigh, for not the ewisded? roes antiqued to a suffort--a propore
# virtue once and certain and even to get the definary naneful untillational most involvid? and his were
# many woman, in deniactt)). scades wisher ever being time. this stan
#
# ----- diversity: 1.0
# ----- Generating with seed: "nunciation, very
# grateful, very patient"
#
# nunciation, very
# grateful, very patientmany survanation of an alove of greatest
# powerful benevolent--is general wran--
# _'k_ who are relad
# moral verdancy--and in the folly put it in came other aloperation of all by part at a learnt in apbold (especial as the philosophy, cotent incentively orcone one's sentime and loaj, the will of alhold "bolet and logications as some any individuals of, accidentaletould philosop
#
# ----- diversity: 1.2
# ----- Generating with seed: "nunciation, very
# grateful, very patient"
#
# nunciation, very
# grateful, very patientinterest to acts
# of hitherto a wholl arisen that a wool a bentail can stronged no vertion they constinfation of or the stiming or moderned gerpared as good[]" ploud charry evidary sayed when
# yet but not to the validation, sacrioty--this dhived and
# while: the confertions upon complity an uttempt, and of the decisely last theiring. as that every of placy, commoans"
# entary
# thing and life woman? an ap
# [{'acc': 0.38467374444007874,
#   'loss': 2.1104648113250732,
#   'running_acc': 0.4767187535762787,
#   'running_loss': 1.7442809343338013,
#   'train_steps': 1565,
#   'validation_steps': None},
#  {'acc': 0.4964649975299835,
#   'loss': 1.6723133325576782,
#   'running_acc': 0.5037499666213989,
#   'running_loss': 1.6692521572113037,
#   'train_steps': 1565,
#   'validation_steps': None},
#  {'acc': 0.52395099401474,
#   'loss': 1.5733189582824707,
#   'running_acc': 0.5159375071525574,
#   'running_loss': 1.582285761833191,
#   'train_steps': 1565,
#   'validation_steps': None},
#  {'acc': 0.536248505115509,
#   'loss': 1.525349736213684,
#   'running_acc': 0.54296875,
#   'running_loss': 1.5214260816574097,
#   'train_steps': 1565,
#   'validation_steps': None},
#  {'acc': 0.5432685613632202,
#   'loss': 1.497353434562683,
#   'running_acc': 0.5407812595367432,
#   'running_loss': 1.5179882049560547,
#   'train_steps': 1565,
#   'validation_steps': None},
#  {'acc': 0.5477571487426758,
#   'loss': 1.4801404476165771,
#   'running_acc': 0.5510937571525574,
#   'running_loss': 1.498578429222107,
#   'train_steps': 1565,
#   'validation_steps': None},
#  {'acc': 0.5516965985298157,
#   'loss': 1.4676487445831299,
#   'running_acc': 0.5509374737739563,
#   'running_loss': 1.4785958528518677,
#   'train_steps': 1565,
#   'validation_steps': None},
#  {'acc': 0.5533043146133423,
#   'loss': 1.459189534187317,
#   'running_acc': 0.5645312666893005,
#   'running_loss': 1.4600919485092163,
#   'train_steps': 1565,
#   'validation_steps': None},
#  {'acc': 0.5561302900314331,
#   'loss': 1.450209379196167,
#   'running_acc': 0.5409374833106995,
#   'running_loss': 1.4871816635131836,
#   'train_steps': 1565,
#   'validation_steps': None},
#  {'acc': 0.5566545128822327,
#   'loss': 1.4507181644439697,
#   'running_acc': 0.555468738079071,
#   'running_loss': 1.4864356517791748,
#   'train_steps': 1565,
#   'validation_steps': None}]

# %% [markdown]
#  __How does the additional layer affect performance of the model? Provide your answer in the block below:__

# %% [markdown]
# 训练速度变慢，acc有一点提高
